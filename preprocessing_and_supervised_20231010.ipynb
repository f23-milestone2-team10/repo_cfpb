# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **<h2> MADS: Milestone II (Team 10) - Preprocessing, Features Engineering, and Supervised Learning</h2>**
# <h3> Topic: Machine learning on duty: solving consumer complaints and improving satisfaction!</h3>
# <h4> Authors: Chih-Han Yeh (yehch), Yi-Hsin Chien (yihsinc), Weiming Chen ( weimingc) </h4>
# <h4> Mentor: Alexis Castellanos</h4>

# %% [markdown]
# **<h3>Project Overview</h3></br>**
# In response to the escalating volume of consumer complaints and the complexities involved in addressing them promptly, our dedicated team is committed to leveraging data-driven strategies to enhance our comprehension of these complaints. Our overarching objective is to develop efficient techniques for managing and resolving complaints by predicting which ones are likely to be disputed by consumers and unveiling concealed patterns or clusters within the narrative of these complaints.

# %% [markdown]
# **<h3>Environment Setting</h3></br>**
# Importing libraries we need for our project.

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in /usr/local/lib/python3.10/dist-packages (2.13.1)

# %%
# Built-in libraries
import re
import string
import warnings

# Third-party libraries for data handling and processing
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from tqdm import tqdm

# Feature extraction
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import KeyedVectors

# Pre-processing
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler, MaxAbsScaler
from imblearn.over_sampling import SMOTE, SMOTENC

# Model selection and evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

# Machine Learning Models
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier


# Deep Learning Libraries
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv1D, GlobalMaxPooling1D, LSTM
from keras.callbacks import EarlyStopping

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt


# Miscellaneous
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
tqdm.pandas()
warnings.filterwarnings("ignore")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# files
file_path_01 = '/content/drive/MyDrive/Colab Notebooks/complaints.csv'

file_path_03 = '/content/drive/MyDrive/Colab Notebooks/GoogleNews-vectors-negative300.bin'

# import DATA
DATA = pd.read_csv(file_path_01)

print(DATA.shape)
# Out:
# (4028530, 18)

# %% [markdown]
# # **CFBP Dataset**

# %% [markdown]
# **•	Where the datasets or API resource is located </br>**
# Our dataset is drawn from the CFPB Consumer Complaint Database, encompassing complaint receipt dates, product types, issues, consumer narratives, and various other attributes. We downloaded the dataset from the link: https://files.consumerfinance.gov/ccdb/complaints.csv.zip.
#
# **•	What formats they returned/used</br>**
# The format of our dataset is a CSV file.
#
# **•	What were the important variables contained in them</br>**
# The important variables are Product, Sub-product, Issue, Sub-issue, Consumer complaint narrative, Company public response, Company, State, Zip code, Company response to Consumer, and Consumer disputed.
#
# **•	How many records you used or retrieved (if using an API)</br>**
# Our dataset contains 4,101,381 entries and is around 2.61 GB.
#
# **•	What time periods they covered (if there is a time element)</br>**
# The period of our dataset is from 2011-12-01 to 2023-09-22.
#
# **•	What initial preprocessing was required to handle noisy or missing data</br>**
# A strategic methodology is essential to address the intricacies of consumer complaints effectively. Firstly, a focused analysis of the "Credit reporting, credit repair services, or other personal consumer reports" category is imperative due to the high frequency of complaints within this segment. Specialized models and analysis pipelines for this category will enable us to extract detailed and specific insights. Before delving into Word Embedding and Feature Vectorization, it's paramount to maintain the integrity of our dataset. We must address columns with persistent missing data, such as "Tags," by removing or blaming them. Essential columns with incomplete data should be rectified using central tendency measures or interpolation. Following this, optimizing our feature set by eliminating redundant or irrelevant attributes, enhancing the model's precision, and reducing overfitting risks is vital. Word Embedding and Feature Vectorization, mainly deriving attributes from the "Consumer complaint narrative," is our subsequent focus. By extracting key insights such as sentiment scores, narrative lengths, and keyword frequencies, we add depth to our dataset. Translating categorical variables, like product types, into numerical formats will further streamline our data structure.

# %% [markdown]
# # **Feature Engineering**

# %% [markdown]
# **Step 1: Deep Dive into Credit Reporting Complaints and few Companies**

# %% [markdown]
# *   **Credit Reporting**
#
# > From our exploratory data analysis (EDA), we discerned that the "Credit reporting, credit repair services, or other personal consumer reports" category constitutes the largest segment of our dataset. Delving further into the Sub-Product columns revealed a pronounced data imbalance. Specifically, credit reporting dominates the data, comprising approximately 54%. As a result, our team has decided to concentrate on credit reporting, ensuring that our insights are precise and pertinent rather than attempting to generalize our analysis across all sub-products. Please see the chart below for a detailed visualization.

# %%
#calculate the share of the credit reporting of the whole dataset
credit = DATA[DATA['Sub-product'] == 'Credit reporting']
print('Credit Reporting accounts for {}% of the dataset'.format((round(len(credit)/len(DATA)*100,1))))
#visualize the imbalance situation
plt.figure(figsize=(30, 12))
DATA['Sub-product'].value_counts().plot(kind='bar')
plt.title('Counts by Sub-Product')
plt.xlabel('Sub-Product')
plt.ylabel('Count (Million)')
plt.show()
# Out:
# Credit Reporting accounts for 53.6% of the dataset

# %% [markdown]
# *   **Few Companies**
#
#
# > From our exploratory data analysis (EDA), we observed that a handful of companies account for a significant portion of the complaint counts. Further examination of the company column showed a notable data disparity, with three particular companies making up roughly 88% of the complaints. Consequently, our team has narrowed our focus on these dominant companies to derive more accurate and contextually relevant insights. For a comprehensive visual representation, please refer to the chart below.

# %%
#calculate the shares of the top three companies of the whole credit reporting dataset
print('Three companies accounts for {}% of the credit dataset'.format((round(credit['Company'].value_counts().head(3).sum()/ len(credit)*100,1))))
#visualize the imbalance situation
plt.figure(figsize=(30, 12))
credit['Company'].value_counts().head(20).plot(kind='bar')
plt.title('Counts by Company')
plt.xlabel('Company')
plt.ylabel('Count')
plt.show()
# Out:
# Three companies accounts for 87.9% of the credit dataset

# %% [markdown]
# **Summary: We narrowed down the dataset to focus on credit reporting and three companies: Equifax, Transunion, and Capital One. **

# %%
# Top 3 companies
company = list(credit['Company'].value_counts().head(3).index)
#credit reporting for top 3 companies
credit_company = credit[credit['Company'].isin(company)]
#refined dataframe is what portion of the original dataset
print('credit_company / original dataset: {}%'.format((round(len(credit_company)/len(DATA)*100,1))))
# Out:
# credit_company / original dataset: 47.1%

# %% [markdown]
# **Step 2: Feature Selection**

# %% [markdown]
# We've excluded the 'Complaint ID', 'Timely response?', 'Consumer consent provided?', 'Submitted via', and 'Tags' from our feature selection. Given that the 'Tags' feature is absent. Moreover, 'Complaint ID' is just a label not related to our focus. Lastly, 'Consumer consent provided?' and 'Submitted via' are removed due to no variance.

# %%
feature_selection = credit_company.drop(columns=['Tags', 'Complaint ID', 'Timely response?', 'Consumer consent provided?', 'Submitted via'])

# %%
feature_selection.head(3)
# Out:
#    Date received                                            Product  \
# 1     2023-08-23  Credit reporting, credit repair services, or o...
# 8     2023-08-23  Credit reporting, credit repair services, or o...
# 11    2023-07-07  Credit reporting, credit repair services, or o...
#
#          Sub-product                                              Issue  \
# 1   Credit reporting               Incorrect information on your report
# 8   Credit reporting  Problem with a credit reporting company's inve...
# 11  Credit reporting               Incorrect information on your report
#
#                                             Sub-issue  \
# 1                       Account information incorrect
# 8   Difficulty submitting a dispute or getting inf...
# 11                Information belongs to someone else
#
#    Consumer complaint narrative  \
# 1                           NaN
# 8                           NaN
# 11                          NaN
#
#                               Company public response  \
# 1   Company has responded to the consumer and the ...
# 8                                                 NaN
# 11                                                NaN
#
#                                 Company State ZIP code Date sent to company  \
# 1   Experian Information Solutions Inc.    GA    30318           2023-08-23
# 8   Experian Information Solutions Inc.    NY    10928           2023-08-23
# 11                        EQUIFAX, INC.    FL    33319           2023-07-07
#
#        Company response to consumer Consumer disputed?
# 1   Closed with non-monetary relief                NaN
# 8                       In progress                NaN
# 11  Closed with non-monetary relief                NaN

# %% [markdown]
# **Step 3: Handling Missing Data**

# %%
#As our focus is on the complaint narrative, we dropped rows with no narrative
clean = feature_selection[feature_selection['Consumer complaint narrative'].notnull()]
#notnull narrativ rows are what portion of the original dataset
print('clean / original dataset: {}%'.format((round(len(clean)/len(DATA)*100,1))))
print(clean.shape)
clean.head(3)
# Out:
# clean / original dataset: 15.7%
# (631737, 13)
#    Date received                                            Product  \
# 24    2023-07-20  Credit reporting, credit repair services, or o...
# 28    2023-07-05  Credit reporting, credit repair services, or o...
# 32    2023-07-05  Credit reporting, credit repair services, or o...
#
#          Sub-product                                              Issue  \
# 24  Credit reporting                        Improper use of your report
# 28  Credit reporting                        Improper use of your report
# 32  Credit reporting  Problem with a credit reporting company's inve...
#
#                                             Sub-issue  \
# 24      Reporting company used your report improperly
# 28      Reporting company used your report improperly
# 32  Their investigation did not fix an error on yo...
#
#                          Consumer complaint narrative  \
# 24  In accordance with the Fair Credit Reporting a...
# 28  My name is XXXX XXXX XXXX XXXX this complaint ...
# 32  I've found that my credit report has erroneous...
#
#                               Company public response  \
# 24  Company has responded to the consumer and the ...
# 28                                                NaN
# 32                                                NaN
#
#                                    Company State ZIP code  \
# 24  TRANSUNION INTERMEDIATE HOLDINGS, INC.    MO    641XX
# 28                           EQUIFAX, INC.    FL    33055
# 32                           EQUIFAX, INC.    MA    01905
#
#    Date sent to company     Company response to consumer Consumer disputed?
# 24           2023-07-20  Closed with non-monetary relief                NaN
# 28           2023-07-05          Closed with explanation                NaN
# 32           2023-07-05  Closed with non-monetary relief                NaN

# %% [markdown]
# **Unexpected Findings**

# %% [markdown]
# > Initially, our intention was to train and test solely on the 'credit reporting' sub-product. However, given that none of the entries in this sub-product have a 'consumer disputed' label, we've chosen to designate this dataset as our test set. Instead, we'll leverage other sub-products with 'disputed' data to predict the 'disputed' labels for the 'credit reporting' sub-product entries. Consequently, this curated dataset has transitioned to serve as our test set. Please see the following results.

# %%
#Here this slice of dataset is filtered by whether the narratives is null or not: clean dataframe
#As we know from the EDA, the consumer-disputed Consumer features are missing after 2018. We divided the dataset into two parts: one with Consumer disputes and one without.
consumer_notnull = clean[clean['Consumer disputed?'].notnull()]
consumer_null = clean[clean['Consumer disputed?'].isnull()]
#show the lengths of each
print('Consumer disputed counts for credit reporting: {}'.format(len(consumer_notnull)))
print('Null Consumer disputed counts for credit reporting: {}'.format(len(consumer_null)))
#Credit reporting does not have consumer disputed data
print('The period of this chunk of the dataset was from {} to {}'.format(clean['Date received'].min(), clean['Date received'].max()))
# Out:
# Consumer disputed counts for credit reporting: 0
# Null Consumer disputed counts for credit reporting: 631737
# The period of this chunk of the dataset was from 2017-04-24 to 2023-08-28

# %% [markdown]
# >As we re-examine the filtered dataset by credit reporting and the top three companies, all entries did not have the consumer disputed data.

# %%
#re-examine the credit_company dataset to see the consumer disputed problem
print('Consumer disputed counts for credit reporting and the top three companies without filtering the narratives: {}'.format(len(credit_company[credit_company['Consumer disputed?'].notnull()])))
print('Null Consumer disputed counts for credit reporting and the top three companies without filtering the narratives:  {}'.format(len(credit_company[credit_company['Consumer disputed?'].isnull()])))
# Out:
# Consumer disputed counts for credit reporting and the top three companies without filtering the narratives: 0
# Null Consumer disputed counts for credit reporting and the top three companies without filtering the narratives:  1897278

# %% [markdown]
# **Re-visit original dataset to examine not credit reporting sub-product**

# %%
#re-examine the DATA to see the consumer disputed problem beside credit-reporting
non_credit = DATA[DATA['Sub-product'] != 'Credit reporting' ]
print('Consumer disputed counts for sub-product other than credit reporting: {}'.format(len(non_credit)))
non_credit.head(3)
# Out:
# Consumer disputed counts for sub-product other than credit reporting: 1869539
#   Date received                                    Product        Sub-product  \
# 0    2023-08-23  Payday loan, title loan, or personal loan   Installment loan
# 3    2023-08-23                Credit card or prepaid card  Store credit card
# 5    2023-08-23                            Debt collection         Other debt
#
#                                 Issue                          Sub-issue  \
# 0        Problem when making payments                                NaN
# 3                    Fees or interest          Charged too much interest
# 5  False statements or representation  Attempted to collect wrong amount
#
#   Consumer complaint narrative  \
# 0                          NaN
# 3                          NaN
# 5                          NaN
#
#                              Company public response  \
# 0                                                NaN
# 3  Company has responded to the consumer and the ...
# 5                                                NaN
#
#                         Company State ZIP code            Tags  \
# 0   OneMain Finance Corporation    NC    27407             NaN
# 3                CITIBANK, N.A.    KY    41018  Older American
# 5  LTD Financial Services, L.P.    NJ    08046   Servicemember
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                        NaN           Web           2023-08-23
# 3                        NaN         Phone           2023-08-23
# 5                        NaN           Web           2023-08-23
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0      Closed with explanation              Yes                NaN
# 3      Closed with explanation              Yes                NaN
# 5                  In progress              Yes                NaN
#
#    Complaint ID
# 0       7448359
# 3       7442765
# 5       7447784

# %% [markdown]
# > From the below counts, we identified around 768 thousand entries with the consumer disputed label, so we will use this chunk of the dataset to build up the model to predict the consumer disputed label for the credit reporting sub-product.

# %%
print('not credit reporting Consumer disputed counts: {}'.format(len(non_credit[non_credit['Consumer disputed?'].notnull()])))
print('not credit reporting Null Consumer disputed counts: {}'.format(len(non_credit[non_credit['Consumer disputed?'].isnull()])))
# Out:
# not credit reporting Consumer disputed counts: 768358
# not credit reporting Null Consumer disputed counts: 1101181

# %% [markdown]
# **Examine the not credit reporting sub-products' distribution**

# %%
# define disputed dataframe
disputed = DATA[(DATA['Sub-product'] != 'Credit reporting') & (DATA['Consumer disputed?'].notnull())]
#calculate the shares of the top three companies of the whole credit reporting dataset
print('Complaint disputed Sub-product accounts for {}% of the original dataset'.format((round(disputed['Product'].value_counts().head(3).sum()/ len(DATA)*100,1))))
#visualize the imbalance situation
plt.figure(figsize=(30, 12))
disputed['Product'].value_counts().head(20).plot(kind='bar')
plt.title('Counts by Sub-product')
plt.xlabel('Sub-product')
plt.ylabel('Count')
plt.show()
# Out:
# Complaint disputed Sub-product accounts for 12.7% of the original dataset

# %% [markdown]
# > We found that the first eleven sub-products account for about 99.99% of the not credit reporting part of the dataset.

# %%
#check the shares of the first 11 Products / all Products
print('Top 11 sub-products account for {}% of the not credit reporting'.format(round(disputed['Product'].value_counts().head(11).sum()/disputed['Product'].value_counts().sum()*100,3)))
# Out:
# Top 11 sub-products account for 99.997% of the not credit reporting

# %% [markdown]
# > As we decided to use the data points with disputed labels, we will use the disputed dataframe as our training set. The below analysis shows the null percent of each feature.

# %%
#check the null % for each feature
train_valid = disputed.drop(columns=['Tags', 'Complaint ID', 'Timely response?', 'Consumer consent provided?', 'Submitted via'])
train_valid.isnull().sum() / len(train_valid) * 100
# Out:
# Date received                    0.000000
# Product                          0.000000
# Sub-product                     30.605525
# Issue                            0.000000
# Sub-issue                       59.265342
# Consumer complaint narrative    78.651358
# Company public response         74.528931
# Company                          0.000000
# State                            0.735334
# ZIP code                         0.501980
# Date sent to company             0.000000
# Company response to consumer     0.000000
# Consumer disputed?               0.000000
# dtype: float64

# %% [markdown]
# > The below analysis checks the null percentage of each feature of the credit reporting slices.

# %%
#check the null % for each feature
consumer_null.isnull().sum() / len(consumer_null) * 100
# Out:
# Date received                     0.000000
# Product                           0.000000
# Sub-product                       0.000000
# Issue                             0.000000
# Sub-issue                         0.963059
# Consumer complaint narrative      0.000000
# Company public response          36.221561
# Company                           0.000000
# State                             0.125527
# ZIP code                          0.000000
# Date sent to company              0.000000
# Company response to consumer      0.000317
# Consumer disputed?              100.000000
# dtype: float64

# %% [markdown]
# > Based on our analyses of the two sets, we observed that the set has significant null values across multiple features. To ensure consistency between the training and test sets, we removed certain features that were deemed redundant or had high missing values. Specifically, we eliminated the 'sub-product' feature because 30% of its values were missing in the training set, whereas none were in the predict set. Instead, we have utilized the 'product' feature, which has complete data in both sets. Similarly, we discarded the 'sub-issue' and retained the 'issue' feature for consistency. We also removed rows in the training set that lacked narratives and omitted the 'company public response' feature due to its substantial missing data in both sets. Finally, considering both convey similar information, we retained the 'zip code' and discarded the 'state' feature. Below two analyses shows the results after our processing.

# %%
train_valid_narr = train_valid[train_valid['Consumer complaint narrative'].notnull()]
train_valid_narr_refine = train_valid_narr.drop(columns=['Sub-product','Sub-issue', 'Company public response', 'State'])
train_valid_narr_refine.isnull().sum() / len(train_valid_narr_refine) * 100
# Out:
# Date received                   0.0
# Product                         0.0
# Issue                           0.0
# Consumer complaint narrative    0.0
# Company                         0.0
# ZIP code                        0.0
# Date sent to company            0.0
# Company response to consumer    0.0
# Consumer disputed?              0.0
# dtype: float64

# %%
#check the null % for each feature
consumer_null_refine = consumer_null.drop(columns=['Sub-product', 'Sub-issue', 'Company public response', 'State'])
consumer_null_refine = consumer_null_refine[consumer_null_refine['Company response to consumer'].notnull()]
consumer_null_refine.isnull().sum() / len(consumer_null_refine) * 100
# Out:
# Date received                     0.0
# Product                           0.0
# Issue                             0.0
# Consumer complaint narrative      0.0
# Company                           0.0
# ZIP code                          0.0
# Date sent to company              0.0
# Company response to consumer      0.0
# Consumer disputed?              100.0
# dtype: float64

# %% [markdown]
# > Transform the date related features into datetime and the calculate the difference between Data received and Date set to company as the new feature "days". Moreover, we converted the labels of the consumer disputed into 0 and 1.

# %%
# convert date received and date sent to company to datetime format, and compute date sent - date received, store in column 'days' as int
train_valid_narr_refine['Date received'] = pd.to_datetime(train_valid_narr_refine['Date received'])
train_valid_narr_refine['Date sent to company'] = pd.to_datetime(train_valid_narr_refine['Date sent to company'])
train_valid_narr_refine['days'] = (train_valid_narr_refine['Date sent to company'] - train_valid_narr_refine['Date received']).dt.days

# drop Date received and Date sent to company columns
train_valid_narr_refine.drop(['Date received', 'Date sent to company'], axis=1, inplace=True)
train_valid_narr_refine.head(3)
# Out:
#              Product                         Issue  \
# 31338       Mortgage  Settlement process and costs
# 31664  Consumer Loan    Managing the loan or lease
# 35599    Credit card              Billing disputes
#
#                             Consumer complaint narrative  \
# 31338  XXXX XXXX, 2016 To Whom It May Concern : I am ...
# 31664  History of account : I am a co-signer on XXXX ...
# 35599  I have excellent credit and the only times I m...
#
#                                   Company ZIP code  \
# 31338     Barrett Financial Group, L.L.C.    92071
# 31664  Bridgecrest Acceptance Corporation    85340
# 35599                 SYNCHRONY FINANCIAL    21229
#
#       Company response to consumer Consumer disputed?  days
# 31338  Closed with monetary relief                Yes    61
# 31664      Closed with explanation                Yes     2
# 35599      Closed with explanation                Yes     0

# %%
# encode disputed column to 0 and 1
train_valid_narr_refine['Consumer disputed?'] = train_valid_narr_refine['Consumer disputed?'].map({'No': 0, 'Yes': 1})
train_valid_narr_refine.head(3)
# Out:
#              Product                         Issue  \
# 31338       Mortgage  Settlement process and costs
# 31664  Consumer Loan    Managing the loan or lease
# 35599    Credit card              Billing disputes
#
#                             Consumer complaint narrative  \
# 31338  XXXX XXXX, 2016 To Whom It May Concern : I am ...
# 31664  History of account : I am a co-signer on XXXX ...
# 35599  I have excellent credit and the only times I m...
#
#                                   Company ZIP code  \
# 31338     Barrett Financial Group, L.L.C.    92071
# 31664  Bridgecrest Acceptance Corporation    85340
# 35599                 SYNCHRONY FINANCIAL    21229
#
#       Company response to consumer  Consumer disputed?  days
# 31338  Closed with monetary relief                   1    61
# 31664      Closed with explanation                   1     2
# 35599      Closed with explanation                   1     0

# %%
# convert date received and date sent to company to datetime format, and compute date sent - date received, store in column 'days' as int
consumer_null_refine['Date received'] = pd.to_datetime(consumer_null_refine['Date received'])
consumer_null_refine['Date sent to company'] = pd.to_datetime(consumer_null_refine['Date sent to company'])
consumer_null_refine['days'] = (consumer_null_refine['Date sent to company'] - consumer_null_refine['Date received']).dt.days

# drop Date received and Date sent to company columns
consumer_null_refine.drop(['Date received', 'Date sent to company'], axis=1, inplace=True)
consumer_null_refine.head(3)
# Out:
#                                               Product  \
# 24  Credit reporting, credit repair services, or o...
# 28  Credit reporting, credit repair services, or o...
# 32  Credit reporting, credit repair services, or o...
#
#                                                 Issue  \
# 24                        Improper use of your report
# 28                        Improper use of your report
# 32  Problem with a credit reporting company's inve...
#
#                          Consumer complaint narrative  \
# 24  In accordance with the Fair Credit Reporting a...
# 28  My name is XXXX XXXX XXXX XXXX this complaint ...
# 32  I've found that my credit report has erroneous...
#
#                                    Company ZIP code  \
# 24  TRANSUNION INTERMEDIATE HOLDINGS, INC.    641XX
# 28                           EQUIFAX, INC.    33055
# 32                           EQUIFAX, INC.    01905
#
#        Company response to consumer Consumer disputed?  days
# 24  Closed with non-monetary relief                NaN     0
# 28          Closed with explanation                NaN     0
# 32  Closed with non-monetary relief                NaN     0

# %% [markdown]
# *   Training Set before Vectorization

# %%
train_df_before_vector = train_valid_narr_refine.copy()
print('Training set: {} rows'.format(len(train_df_before_vector)))
# Out:
# Training set: 164034 rows

# %% [markdown]
# *   Prediction set before Vectorization

# %%
predict_df_before_vector = consumer_null_refine.copy()
print('Test set: {} rows'.format(len(predict_df_before_vector)))
# Out:
# Test set: 631735 rows

# %% [markdown]
# **Step 4: Word Embedding and Feature Vectorization**

# %% [markdown]
# <font color='orange'> **Grasp a fractoin of sample from the original dataframes for testing purpose. Please comment out the below line before training on the complete dataframe.   **<font>

# %%
# Grasp a fractoin of sample from dataframe just for testing purpose
train_df_before_vector = train_df_before_vector.sample(frac=0.2, random_state=42)

predict_df_before_vector = predict_df_before_vector.sample(frac=0.2, random_state=42)

# %%
# import word2vec model (this take a while to load)
word2vec = KeyedVectors.load_word2vec_format(file_path_03, binary=True)

# %%
# helper func: preprocess the narrative column

def preprocess_narrative(text):

    # Lowercase
    text = text.lower()

    # Remove XXXX like pattern
    text = re.sub(r'x{2,}', '', text)

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Remove stopwords
    text = " ".join([word for word in text.split() if word not in stop_words])

    # Remove numbers
    text = re.sub(r'\d+', '', text)

    # Remove non-alphanumeric characters
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)

    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text)

    # Remove leading and trailing spaces
    text = text.strip()

    return text

# %% [markdown]
# > Approach: Mixture of categorical columns and TFIDF w2v matrix

# %%
# preprocess narrative column and store in narrative_processed column
train_df_before_vector['narrative_processed'] = train_df_before_vector['Consumer complaint narrative'].progress_apply(preprocess_narrative)
predict_df_before_vector['narrative_processed'] = predict_df_before_vector['Consumer complaint narrative'].progress_apply(preprocess_narrative)
# Out:
# 100%|██████████| 32807/32807 [00:03<00:00, 9592.21it/s]
# 100%|██████████| 126347/126347 [00:11<00:00, 11100.00it/s]

# %%
# instantiate tfidf

tfidf = TfidfVectorizer()

# fit and transform tfidf vectorizer on narrative_processed column
tfidf.fit(train_df_before_vector.narrative_processed)

# get tfidf feature names
tfidf_features = tfidf.get_feature_names_out()

# get tfidf weights
tfidf_weights = tfidf.idf_

# %%
# define a function get mean word2vec vector for a narrative

def get_mean_word2vec(narrative):

    # initialize vector
    vector = np.zeros(300)

    # get all words in narrative
    words = narrative.split()
    num_words = len(words)

    if num_words == 0:  # edge case: empty narrative
        return vector

    # calculate word vectors using list comprehension
    word_vectors = [word2vec[word] for word in words if word in word2vec]

    if word_vectors:
        vector = np.mean(word_vectors, axis=0)

    return vector


# define a function get mean tfidf weighted word2vec vector for a narrative
def get_mean_tfidf_weighted_word2vec(narrative):

    # initialize vector
    vector = np.zeros(300)

    # get all words in narrative
    words = narrative.split()
    num_words = len(words)

    if num_words == 0:  # edge case: empty narrative
        return vector

    # pre-calculate word-to-index mapping for tfidf_features for O(1) lookup
    word_to_index = {word: idx for idx, word in enumerate(tfidf_features)}

    # calculate word vectors using list comprehension
    word_vectors = [
        word2vec[word] * tfidf_weights[word_to_index[word]]
        for word in words if word in word2vec and word in word_to_index
    ]

    if word_vectors:
        vector = np.sum(word_vectors, axis=0) / num_words

    return vector

# %%
# compute mean tfidf weighted word2vec vector for each narrative (take a while)
train_df_before_vector['narrative_tw'] = train_df_before_vector['narrative_processed'].progress_apply(get_mean_tfidf_weighted_word2vec)
predict_df_before_vector['narrative_tw'] = predict_df_before_vector['narrative_processed'].progress_apply(get_mean_tfidf_weighted_word2vec)
# convert train_df_before_vector['narrative_tw'] to numpy array tw_array
tw_array_train = np.array(train_df_before_vector.narrative_tw.tolist())
# convert test_df_before_vector['narrative_tw'] to numpy array tw_array
tw_array_predict = np.array(predict_df_before_vector.narrative_tw.tolist())
# print shape of tw_array
print('Train: {}'.format(tw_array_train.shape))
print('Test: {}'.format(tw_array_predict.shape))
# Out:
# 100%|██████████| 32807/32807 [03:39<00:00, 149.35it/s]
# 100%|██████████| 126347/126347 [15:29<00:00, 135.97it/s]
# Train: (32807, 300)
# Test: (126347, 300)

# %%
# copy target column to y
y = train_df_before_vector['Consumer disputed?'].copy()

# %%
train_df_before_vector.columns
# Out:
# Index(['Product', 'Issue', 'Consumer complaint narrative', 'Company',
#        'ZIP code', 'Company response to consumer', 'Consumer disputed?',
#        'days', 'narrative_processed', 'narrative_tw'],
#       dtype='object')

# %%
# drop Consumer complaint narrative, narrative_processed, Consumer disputed? columns
train_df_before_vector.drop(['Consumer complaint narrative', 'narrative_processed', 'narrative_tw', 'Consumer disputed?'], axis=1, inplace=True)
predict_df_before_vector.drop(['Consumer complaint narrative', 'narrative_processed', 'narrative_tw', 'Consumer disputed?'], axis=1, inplace=True)

# %%
train_df_before_vector.nunique()
# Out:
# Product                           12
# Issue                             90
# Company                         1834
# ZIP code                        6172
# Company response to consumer       5
# days                             142
# dtype: int64

# %%
predict_df_before_vector.nunique()
# Out:
# Product                            2
# Issue                             11
# Company                            3
# ZIP code                        6521
# Company response to consumer       4
# days                              65
# dtype: int64

# %%
# concatenate tw_array_train with train_df_before_vector
X = np.concatenate((tw_array_train, train_df_before_vector), axis=1)
X_predict = np.concatenate((tw_array_predict, predict_df_before_vector), axis=1)


# check shape of X
print('X.shape: {}'.format(X.shape))
print('X_predict.shape: {}'.format(X_predict.shape))
print('y.shape: {}'.format(y.shape))
# Out:
# X.shape: (32807, 306)
# X_predict.shape: (126347, 306)
# y.shape: (32807,)

# %%
tw_array_train.shape
# Out:
# (32807, 300)

# %%
train_df_before_vector.shape
# Out:
# (32807, 6)

# %%
categorical_columns = list(range(300, 306))

# smoote to oversample minority class
smote = SMOTENC(random_state=42, categorical_features = categorical_columns)
X_smote, y_smote = smote.fit_resample(X, y)

# print shape of X_smote, y_smote
print(X_smote.shape, y_smote.shape)
# Out:
# (51338, 306) (51338,)

# %% [markdown]
# # Run the models and evaluations

# %% [markdown]
# To enhance the robustness of our predictive models' evaluation, we are employing K-fold cross-validation across the models in our analysis.

# %%
# !pip install scikeras[tensorflow]
# !pip install scikit-optimize
from sklearn.model_selection import cross_val_score
from sklearn.pipeline import Pipeline
from scikeras.wrappers import KerasClassifier
from sklearn import metrics
from skopt import BayesSearchCV
from sklearn.model_selection import GridSearchCV
# Out:
# Collecting scikeras[tensorflow]
#   Downloading scikeras-0.11.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.10/dist-packages (from scikeras[tensorflow]) (23.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikeras[tensorflow]) (1.2.2)
# Requirement already satisfied: tensorflow>=2.11.0 in /usr/local/lib/python3.10/dist-packages (from scikeras[tensorflow]) (2.13.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras[tensorflow]) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras[tensorflow]) (1.11.3)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras[tensorflow]) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikeras[tensorflow]) (3.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (1.59.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (3.9.0)
# Requirement already satisfied: keras<2.14,>=2.13.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (2.13.1)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.11.0->scikeras[tensorflow]) (0.34.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.11.0->scikeras[tensorflow]) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (3.0.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.21.0->tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow>=2.11.0->scikeras[tensorflow]) (3.2.2)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.11.0
# Collecting scikit-optimize
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.3.2)
# Collecting pyaml>=16.9 (from scikit-optimize)
#   Downloading pyaml-23.9.7-py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.23.5)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.11.3)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.2.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->scikit-optimize) (3.2.0)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-23.9.7 scikit-optimize-0.9.0

# %% [markdown]
# We also conduct one-hot encoding for categorical columns before model training as many models don't accept categorical data.

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

categorical_features = categorical_columns

# Create a ColumnTransformer to apply one-hot encoding
preprocessor = ColumnTransformer(
    transformers=[
        ('OneHot', OneHotEncoder(sparse=False), categorical_features)
    ],
    remainder='passthrough'  # Pass through the non-categorical columns
)

# Apply one-hot encoding to our X_smote data
X_smote_encoded = preprocessor.fit_transform(X_smote)

# %%
# train with logistic regression and do cross-validation, wrap in a function

def cross_val_lr(X_smote_encoded, y_smote, k):

    # Define a pipeline consisting of preprocessing and model
    pipe = Pipeline([('scaler', StandardScaler()), ('classifier', LogisticRegression(max_iter=1000, random_state=42))])

    # Perform 5-fold cross-validation with the pipeline
    scores = cross_val_score(pipe, X_smote_encoded, y_smote, cv=k, scoring = "f1_macro")

    # print f1 score
    print(f"Mean score of cross validation: {scores.mean()}")
    return scores.mean()



# train naive bayes and do cross-validation

def cross_val_naive_bayes(X_smote_encoded, y_smote, k):

    # Define a pipeline consisting of preprocessing and model
    # scale values as nb not working with negative
    pipe = Pipeline([('scaler', MinMaxScaler()), ('classifier', MultinomialNB())])

    # Perform 5-fold cross-validation and get scores
    scores = cross_val_score(pipe, X_smote_encoded, y_smote, cv=k, scoring = "f1_macro")

    # print f1 score
    print(f"Mean score of cross validation: {scores.mean()}")

    return scores.mean()

# train lightgbm and do cross-validation

def cross_val_lgbm(X_smote_encoded, y_smote, k):

    # instantiate lightgbm model
    classifier = LGBMClassifier(random_state=42)

    # Perform 5-fold cross-validation and get scores
    scores = cross_val_score(classifier, X_smote_encoded, y_smote, cv=k, scoring = "f1_macro")

    # print f1 score
    print(f"Mean score of cross validation: {scores.mean()}")

    return scores.mean()


# train with xgboost

warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", message="Starting in XGBoost")

def cross_val_xgb(X_smote_encoded, y_smote, k):

    # instantiate xgboost model
    classifier = XGBClassifier(random_state=42, n_jobs=-1)

    # Perform 5-fold cross-validation and get scores
    scores = cross_val_score(classifier, X_smote_encoded, y_smote, cv=k, scoring = "f1_macro")

    # print f1 score
    print(f"Mean score of cross validation: {scores.mean()}")

    return scores.mean()


# catboost in a function

def cross_val_catboost(X_smote_encoded, y_smote, k):

    # instantiate catboost model
    classifier = CatBoostClassifier(random_state=42)

    # Perform 5-fold cross-validation and get scores
    scores = cross_val_score(classifier, X_smote_encoded, y_smote, cv=k, scoring = "f1_macro")

    # print f1 score
    print(f"Mean score of cross validation: {scores.mean()}")

    return scores.mean()


# train ann

def create_ann_model(X_smote_encoded):

    # instantiate ann model
    ann = Sequential()

    # add input layer
    ann.add(Dense(128, activation='relu', input_shape=(X_smote_encoded.shape[1],)))

    # add hidden layers
    ann.add(Dense(64, activation='relu'))
    ann.add(Dense(32, activation='relu'))
    ann.add(Dense(16, activation='relu'))

    # add output layer
    ann.add(Dense(1, activation='sigmoid'))

    # compile model
    ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    return ann

# %%
# Check the mean F1 score for logistic regression

model_lr = cross_val_lr(X_smote_encoded, y_smote, k=5)
# Out:
# Mean score of cross validation: 0.7671217148060948

# %%
# Check the mean F1 score for naive bayes,

model_nb = cross_val_naive_bayes(X_smote_encoded, y_smote, k=5)
# Out:
# Mean score of cross validation: 0.7480194113842046

# %%
# Check the mean F1 score for lightgbm

model_lgbm = cross_val_lgbm(X_smote_encoded, y_smote, k=5)
# Out:
# [LightGBM] [Info] Number of positive: 20535, number of negative: 20535
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.139347 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 77886
# [LightGBM] [Info] Number of data points in the train set: 41070, number of used features: 993
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 20535, number of negative: 20535
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.141779 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 77868
# [LightGBM] [Info] Number of data points in the train set: 41070, number of used features: 984
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 20535, number of negative: 20535
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.133425 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 77862
# [LightGBM] [Info] Number of data points in the train set: 41070, number of used features: 981
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Number of positive: 20536, number of negative: 20535
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.140896 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 77864
# [LightGBM] [Info] Number of data points in the train set: 41071, number of used features: 982
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500012 -> initscore=0.000049
# [LightGBM] [Info] Start training from score 0.000049
# [LightGBM] [Info] Number of positive: 20535, number of negative: 20536
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.135555 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 77846
# [LightGBM] [Info] Number of data points in the train set: 41071, number of used features: 973
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.499988 -> initscore=-0.000049
# [LightGBM] [Info] Start training from score -0.000049
# Mean score of cross validation: 0.7635957241614094

# %%
# Check the mean F1 score for xgboost

model_xgb = cross_val_xgb(X_smote_encoded, y_smote, k=5)
# Out:
# Mean score of cross validation: 0.7784523229272093

# %%
# Check the mean F1 score for catboost

model_catboost = cross_val_catboost(X_smote_encoded, y_smote, k=5)
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# 987:	learn: 0.3853239	total: 42.7s	remaining: 519ms
# 988:	learn: 0.3852150	total: 42.8s	remaining: 476ms
# 989:	learn: 0.3851226	total: 42.8s	remaining: 432ms
# 990:	learn: 0.3849889	total: 42.8s	remaining: 389ms
# 991:	learn: 0.3848795	total: 42.9s	remaining: 346ms
# 992:	learn: 0.3847753	total: 42.9s	remaining: 303ms
# 993:	learn: 0.3846520	total: 43s	remaining: 259ms
# 994:	learn: 0.3844196	total: 43s	remaining: 216ms
# 995:	learn: 0.3843086	total: 43.1s	remaining: 173ms
# 996:	learn: 0.3842065	total: 43.1s	remaining: 130ms
# 997:	learn: 0.3840636	total: 43.1s	remaining: 86.5ms
# 998:	learn: 0.3839799	total: 43.2s	remaining: 43.2ms
# 999:	learn: 0.3839195	total: 43.2s	remaining: 0us
# Mean score of cross validation: 0.7805034286899517

# %%
# train ann
model_ann = create_ann_model(X_smote_encoded)

# Instantiate KerasClassifier with ANN model creation function
ann_classifier = KerasClassifier(build_fn=create_ann_model(X_smote_encoded), epochs=10, batch_size=32, verbose=0)

# conduct cross validation and get scores
scores = cross_val_score(ann_classifier, X_smote_encoded, y_smote, cv=5, scoring = "f1_macro")

# Check the mean F1 score for ann
print(f"Mean score of cross validation: {scores.mean()}")
# Out:
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# WARNING:tensorflow:Detecting that an object or model or tf.train.Checkpoint is being deleted with unrestored values. See the following logs for the specific values in question. To silence these warnings, use `status.expect_partial()`. See https://www.tensorflow.org/api_docs/python/tf/train/Checkpoint#restorefor details about the status object returned by the restore function.
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.0.count
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.total
# WARNING:tensorflow:Value in checkpoint could not be found in the restored object: (root).keras_api.metrics.1.count
# Mean score of cross validation: 0.8027894013577903

# %% [markdown]
# As seen above, ANN model outputs the highest f1-score through k-fold cross validation with f1 score of around 0.8. Other than ANN, CatBoost's performance takes second space with f1 score of 0.78. We decide to use Bayesian optimization to perform a hyperparameter search to find the optimized hyperparameters for the model.

# %%
# train test split, 20% test, random_state=42, stratify=y_smote
X_smote_train, X_smote_test, y_smote_train, y_smote_test = train_test_split(X_smote_encoded, y_smote, stratify=y_smote, random_state=42, test_size=0.2)

# print shape
print(X_smote_train.shape, X_smote_test.shape, y_smote_train.shape, y_smote_test.shape)
# Out:
# (41070, 8555) (10268, 8555) (41070,) (10268,)

# %%
def bayes_search_catboost(X_smote_train, y_smote_train, search_space, cv=5, scoring='f1_macro'):

    # instantiate catboost model
    classifier = CatBoostClassifier(random_state=42)

    # Create BayesSearchCV object with pipeline
    opt = BayesSearchCV(
    estimator=classifier,
    search_spaces=search_space,
    cv=5,
    scoring="f1_macro",
    random_state=42,
    n_iter=3,
    verbose=1,
)

    # Fit the search to our data
    opt.fit(X_smote_train, y_smote_train)

    print("Best Hyperparameters: %s" % str(opt.best_params_))
    print("val. F1 score: %s" % opt.best_score_)
    print("test F1 score: %s" % opt.score(X_smote_test, y_smote_test))

    return opt.best_score_

# %%
search_space = {'depth': (3, 10),'learning_rate': (0.01, 0.5)}

bayes_search_catboost(X_smote_train, y_smote_train, search_space=search_space, cv=5, scoring='f1_macro')
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# 984:	learn: 0.0281269	total: 2m 54s	remaining: 2.66s
# 985:	learn: 0.0281198	total: 2m 54s	remaining: 2.48s
# 986:	learn: 0.0278559	total: 2m 55s	remaining: 2.31s
# 987:	learn: 0.0278551	total: 2m 55s	remaining: 2.13s
# 988:	learn: 0.0278361	total: 2m 55s	remaining: 1.95s
# 989:	learn: 0.0278357	total: 2m 55s	remaining: 1.77s
# 990:	learn: 0.0278323	total: 2m 55s	remaining: 1.6s
# 991:	learn: 0.0278262	total: 2m 55s	remaining: 1.42s
# 992:	learn: 0.0277737	total: 2m 56s	remaining: 1.24s
# 993:	learn: 0.0277691	total: 2m 56s	remaining: 1.06s
# 994:	learn: 0.0277687	total: 2m 56s	remaining: 887ms
# 995:	learn: 0.0275403	total: 2m 56s	remaining: 709ms
# 996:	learn: 0.0275402	total: 2m 56s	remaining: 532ms
# 997:	learn: 0.0275401	total: 2m 56s	remaining: 355ms
# 998:	learn: 0.0273267	total: 2m 57s	remaining: 177ms
# 999:	learn: 0.0273236	total: 2m 57s	remaining: 0us
# Best Hyperparameters: OrderedDict([('depth', 9), ('learning_rate', 0.4428244859166225)])
# val. F1 score: 0.8201927412776042
# test F1 score: 0.8348265894912072
# 0.8201927412776042

# %% [markdown]
# The score on test set and validation set look both fine! We then plot a confusion matrix to check the Precision and Recall situation.

# %%
# set the CatBoost classifier with the best hyperparameters from BayesSearchCV
catboost = CatBoostClassifier(random_seed=42, learning_rate=0.4428244859166225, depth=9)

# fit model
catboost.fit(X_smote_train, y_smote_train)

# predict on test set
y_smote_pred = catboost.predict(X_smote_test)
# Out:
# 0:	learn: 0.6262378	total: 227ms	remaining: 3m 46s
# 1:	learn: 0.5936084	total: 402ms	remaining: 3m 20s
# 2:	learn: 0.5737889	total: 573ms	remaining: 3m 10s
# 3:	learn: 0.5587808	total: 756ms	remaining: 3m 8s
# 4:	learn: 0.5464429	total: 937ms	remaining: 3m 6s
# 5:	learn: 0.5370968	total: 1.13s	remaining: 3m 6s
# 6:	learn: 0.5293019	total: 1.32s	remaining: 3m 6s
# 7:	learn: 0.5198795	total: 1.52s	remaining: 3m 8s
# 8:	learn: 0.5142713	total: 1.71s	remaining: 3m 8s
# 9:	learn: 0.5060271	total: 1.92s	remaining: 3m 9s
# 10:	learn: 0.4989073	total: 2.11s	remaining: 3m 10s
# 11:	learn: 0.4904025	total: 2.33s	remaining: 3m 11s
# 12:	learn: 0.4857734	total: 2.54s	remaining: 3m 13s
# 13:	learn: 0.4811017	total: 2.75s	remaining: 3m 13s
# 14:	learn: 0.4759889	total: 2.95s	remaining: 3m 13s
# 15:	learn: 0.4696141	total: 3.15s	remaining: 3m 13s
# 16:	learn: 0.4651513	total: 3.36s	remaining: 3m 14s
# 17:	learn: 0.4622572	total: 3.55s	remaining: 3m 13s
# 18:	learn: 0.4550666	total: 3.76s	remaining: 3m 13s
# 19:	learn: 0.4499084	total: 3.97s	remaining: 3m 14s
# 20:	learn: 0.4460897	total: 4.16s	remaining: 3m 14s
# 339:	learn: 0.1167291	total: 1m	remaining: 1m 57s
# 340:	learn: 0.1166070	total: 1m	remaining: 1m 57s
# 341:	learn: 0.1164903	total: 1m 1s	remaining: 1m 57s
# 342:	learn: 0.1157021	total: 1m 1s	remaining: 1m 57s
# 343:	learn: 0.1156673	total: 1m 1s	remaining: 1m 57s
# 344:	learn: 0.1146627	total: 1m 1s	remaining: 1m 56s
# 345:	learn: 0.1134738	total: 1m 1s	remaining: 1m 56s
# 346:	learn: 0.1122805	total: 1m 1s	remaining: 1m 56s
# 347:	learn: 0.1122387	total: 1m 2s	remaining: 1m 56s
# 348:	learn: 0.1120793	total: 1m 2s	remaining: 1m 56s
# 349:	learn: 0.1117489	total: 1m 2s	remaining: 1m 55s
# 350:	learn: 0.1117075	total: 1m 2s	remaining: 1m 55s
# 351:	learn: 0.1116749	total: 1m 2s	remaining: 1m 55s
# 352:	learn: 0.1116186	total: 1m 2s	remaining: 1m 55s
# 353:	learn: 0.1115006	total: 1m 3s	remaining: 1m 55s
# 354:	learn: 0.1114328	total: 1m 3s	remaining: 1m 54s
# 355:	learn: 0.1110819	total: 1m 3s	remaining: 1m 54s
# 356:	learn: 0.1110210	total: 1m 3s	remaining: 1m 54s
# 357:	learn: 0.1099783	total: 1m 3s	remaining: 1m 54s
# 358:	learn: 0.1099244	total: 1m 3s	remaining: 1m 54s
# 359:	learn: 0.1097715	total: 1m 4s	remaining: 1m 54s
# 360:	learn: 0.1096592	total: 1m 4s	remaining: 1m 53s
# 361:	learn: 0.1096282	total: 1m 4s	remaining: 1m 53s
# 362:	learn: 0.1093786	total: 1m 4s	remaining: 1m 53s
# 363:	learn: 0.1092927	total: 1m 4s	remaining: 1m 53s
# 364:	learn: 0.1092172	total: 1m 5s	remaining: 1m 53s
# 365:	learn: 0.1081438	total: 1m 5s	remaining: 1m 52s
# 366:	learn: 0.1073689	total: 1m 5s	remaining: 1m 52s
# 367:	learn: 0.1073373	total: 1m 5s	remaining: 1m 52s
# 368:	learn: 0.1062851	total: 1m 5s	remaining: 1m 52s
# 369:	learn: 0.1062090	total: 1m 5s	remaining: 1m 52s
# 370:	learn: 0.1061551	total: 1m 6s	remaining: 1m 51s
# 371:	learn: 0.1056935	total: 1m 6s	remaining: 1m 51s
# 372:	learn: 0.1056625	total: 1m 6s	remaining: 1m 51s
# 373:	learn: 0.1054365	total: 1m 6s	remaining: 1m 51s
# 374:	learn: 0.1051423	total: 1m 6s	remaining: 1m 51s
# 375:	learn: 0.1044157	total: 1m 6s	remaining: 1m 51s
# 376:	learn: 0.1043857	total: 1m 7s	remaining: 1m 50s
# 377:	learn: 0.1043088	total: 1m 7s	remaining: 1m 50s
# 378:	learn: 0.1042671	total: 1m 7s	remaining: 1m 50s
# 379:	learn: 0.1042167	total: 1m 7s	remaining: 1m 50s
# 380:	learn: 0.1041899	total: 1m 7s	remaining: 1m 50s
# 381:	learn: 0.1029982	total: 1m 7s	remaining: 1m 49s
# 382:	learn: 0.1028571	total: 1m 8s	remaining: 1m 49s
# 471:	learn: 0.0831859	total: 1m 23s	remaining: 1m 33s
# 472:	learn: 0.0831170	total: 1m 23s	remaining: 1m 33s
# 473:	learn: 0.0824717	total: 1m 23s	remaining: 1m 33s
# 474:	learn: 0.0824454	total: 1m 24s	remaining: 1m 33s
# 475:	learn: 0.0823835	total: 1m 24s	remaining: 1m 32s
# 476:	learn: 0.0823542	total: 1m 24s	remaining: 1m 32s
# 477:	learn: 0.0823123	total: 1m 24s	remaining: 1m 32s
# 478:	learn: 0.0821603	total: 1m 24s	remaining: 1m 32s
# 479:	learn: 0.0820683	total: 1m 25s	remaining: 1m 32s
# 480:	learn: 0.0820264	total: 1m 25s	remaining: 1m 31s
# 481:	learn: 0.0818741	total: 1m 25s	remaining: 1m 31s
# 482:	learn: 0.0818546	total: 1m 25s	remaining: 1m 31s
# 483:	learn: 0.0810065	total: 1m 25s	remaining: 1m 31s
# 484:	learn: 0.0809880	total: 1m 25s	remaining: 1m 31s
# 485:	learn: 0.0809351	total: 1m 26s	remaining: 1m 31s
# 486:	learn: 0.0808168	total: 1m 26s	remaining: 1m 30s
# 487:	learn: 0.0807699	total: 1m 26s	remaining: 1m 30s
# 488:	learn: 0.0806878	total: 1m 26s	remaining: 1m 30s
# 489:	learn: 0.0806709	total: 1m 26s	remaining: 1m 30s
# 490:	learn: 0.0801252	total: 1m 27s	remaining: 1m 30s
# 491:	learn: 0.0801070	total: 1m 27s	remaining: 1m 30s
# 492:	learn: 0.0797480	total: 1m 27s	remaining: 1m 29s
# 493:	learn: 0.0797188	total: 1m 27s	remaining: 1m 29s
# 494:	learn: 0.0795614	total: 1m 27s	remaining: 1m 29s
# 495:	learn: 0.0795348	total: 1m 28s	remaining: 1m 29s
# 496:	learn: 0.0792151	total: 1m 28s	remaining: 1m 29s
# 497:	learn: 0.0789036	total: 1m 28s	remaining: 1m 29s
# 498:	learn: 0.0788808	total: 1m 28s	remaining: 1m 28s
# 499:	learn: 0.0788198	total: 1m 28s	remaining: 1m 28s
# 500:	learn: 0.0783279	total: 1m 28s	remaining: 1m 28s
# 501:	learn: 0.0781362	total: 1m 29s	remaining: 1m 28s
# 502:	learn: 0.0781166	total: 1m 29s	remaining: 1m 28s
# 503:	learn: 0.0777933	total: 1m 29s	remaining: 1m 28s
# 504:	learn: 0.0777520	total: 1m 29s	remaining: 1m 27s
# 505:	learn: 0.0769116	total: 1m 29s	remaining: 1m 27s
# 506:	learn: 0.0768922	total: 1m 30s	remaining: 1m 27s
# 507:	learn: 0.0768583	total: 1m 30s	remaining: 1m 27s
# 508:	learn: 0.0762758	total: 1m 30s	remaining: 1m 27s
# 509:	learn: 0.0762627	total: 1m 30s	remaining: 1m 26s
# 510:	learn: 0.0762183	total: 1m 30s	remaining: 1m 26s
# 511:	learn: 0.0761757	total: 1m 30s	remaining: 1m 26s
# 512:	learn: 0.0761343	total: 1m 31s	remaining: 1m 26s
# 513:	learn: 0.0759881	total: 1m 31s	remaining: 1m 26s
# 514:	learn: 0.0759681	total: 1m 31s	remaining: 1m 26s
# 515:	learn: 0.0758211	total: 1m 31s	remaining: 1m 25s
# 516:	learn: 0.0756776	total: 1m 31s	remaining: 1m 25s
# 517:	learn: 0.0756609	total: 1m 31s	remaining: 1m 25s
# 518:	learn: 0.0750126	total: 1m 32s	remaining: 1m 25s
# 519:	learn: 0.0749921	total: 1m 32s	remaining: 1m 25s
# 520:	learn: 0.0749454	total: 1m 32s	remaining: 1m 24s
# 521:	learn: 0.0747568	total: 1m 32s	remaining: 1m 24s
# 522:	learn: 0.0747407	total: 1m 32s	remaining: 1m 24s
# 523:	learn: 0.0747089	total: 1m 32s	remaining: 1m 24s
# 524:	learn: 0.0745392	total: 1m 33s	remaining: 1m 24s
# 525:	learn: 0.0742036	total: 1m 33s	remaining: 1m 24s
# 526:	learn: 0.0737241	total: 1m 33s	remaining: 1m 23s
# 527:	learn: 0.0736721	total: 1m 33s	remaining: 1m 23s
# 528:	learn: 0.0730966	total: 1m 33s	remaining: 1m 23s
# 529:	learn: 0.0730764	total: 1m 33s	remaining: 1m 23s
# 530:	learn: 0.0723461	total: 1m 34s	remaining: 1m 23s
# 531:	learn: 0.0723127	total: 1m 34s	remaining: 1m 22s
# 532:	learn: 0.0722756	total: 1m 34s	remaining: 1m 22s
# 533:	learn: 0.0721487	total: 1m 34s	remaining: 1m 22s
# 534:	learn: 0.0720469	total: 1m 34s	remaining: 1m 22s
# 535:	learn: 0.0712944	total: 1m 35s	remaining: 1m 22s
# 536:	learn: 0.0712674	total: 1m 35s	remaining: 1m 22s
# 537:	learn: 0.0712516	total: 1m 35s	remaining: 1m 21s
# 538:	learn: 0.0712359	total: 1m 35s	remaining: 1m 21s
# 539:	learn: 0.0712019	total: 1m 35s	remaining: 1m 21s
# 540:	learn: 0.0710239	total: 1m 35s	remaining: 1m 21s
# 541:	learn: 0.0709996	total: 1m 36s	remaining: 1m 21s
# 542:	learn: 0.0708556	total: 1m 36s	remaining: 1m 20s
# 543:	learn: 0.0707103	total: 1m 36s	remaining: 1m 20s
# 544:	learn: 0.0706965	total: 1m 36s	remaining: 1m 20s
# 545:	learn: 0.0702971	total: 1m 36s	remaining: 1m 20s
# 546:	learn: 0.0702703	total: 1m 36s	remaining: 1m 20s
# 547:	learn: 0.0702460	total: 1m 37s	remaining: 1m 20s
# 548:	learn: 0.0702311	total: 1m 37s	remaining: 1m 19s
# 549:	learn: 0.0698893	total: 1m 37s	remaining: 1m 19s
# 550:	learn: 0.0693316	total: 1m 37s	remaining: 1m 19s
# 551:	learn: 0.0692296	total: 1m 37s	remaining: 1m 19s
# 552:	learn: 0.0687698	total: 1m 37s	remaining: 1m 19s
# 553:	learn: 0.0687553	total: 1m 38s	remaining: 1m 19s
# 554:	learn: 0.0683044	total: 1m 38s	remaining: 1m 18s
# 555:	learn: 0.0682894	total: 1m 38s	remaining: 1m 18s
# 556:	learn: 0.0679614	total: 1m 38s	remaining: 1m 18s
# 557:	learn: 0.0679457	total: 1m 38s	remaining: 1m 18s
# 602:	learn: 0.0619551	total: 1m 46s	remaining: 1m 10s
# 603:	learn: 0.0619432	total: 1m 46s	remaining: 1m 10s
# 604:	learn: 0.0619131	total: 1m 47s	remaining: 1m 9s
# 605:	learn: 0.0617111	total: 1m 47s	remaining: 1m 9s
# 606:	learn: 0.0616992	total: 1m 47s	remaining: 1m 9s
# 607:	learn: 0.0616784	total: 1m 47s	remaining: 1m 9s
# 608:	learn: 0.0613323	total: 1m 47s	remaining: 1m 9s
# 609:	learn: 0.0613176	total: 1m 47s	remaining: 1m 9s
# 610:	learn: 0.0613059	total: 1m 48s	remaining: 1m 8s
# 611:	learn: 0.0607442	total: 1m 48s	remaining: 1m 8s
# 612:	learn: 0.0605199	total: 1m 48s	remaining: 1m 8s
# 613:	learn: 0.0605089	total: 1m 48s	remaining: 1m 8s
# 614:	learn: 0.0604978	total: 1m 48s	remaining: 1m 8s
# 615:	learn: 0.0604138	total: 1m 48s	remaining: 1m 7s
# 616:	learn: 0.0601740	total: 1m 49s	remaining: 1m 7s
# 617:	learn: 0.0601581	total: 1m 49s	remaining: 1m 7s
# 618:	learn: 0.0600666	total: 1m 49s	remaining: 1m 7s
# 619:	learn: 0.0599767	total: 1m 49s	remaining: 1m 7s
# 620:	learn: 0.0599352	total: 1m 49s	remaining: 1m 7s
# 621:	learn: 0.0599086	total: 1m 50s	remaining: 1m 6s
# 622:	learn: 0.0597436	total: 1m 50s	remaining: 1m 6s
# 623:	learn: 0.0596553	total: 1m 50s	remaining: 1m 6s
# 624:	learn: 0.0596387	total: 1m 50s	remaining: 1m 6s
# 625:	learn: 0.0596285	total: 1m 50s	remaining: 1m 6s
# 626:	learn: 0.0594653	total: 1m 50s	remaining: 1m 5s
# 627:	learn: 0.0588767	total: 1m 51s	remaining: 1m 5s
# 628:	learn: 0.0588648	total: 1m 51s	remaining: 1m 5s
# 629:	learn: 0.0588317	total: 1m 51s	remaining: 1m 5s
# 630:	learn: 0.0588081	total: 1m 51s	remaining: 1m 5s
# 631:	learn: 0.0586771	total: 1m 51s	remaining: 1m 5s
# 632:	learn: 0.0586516	total: 1m 51s	remaining: 1m 4s
# 633:	learn: 0.0586396	total: 1m 52s	remaining: 1m 4s
# 634:	learn: 0.0584354	total: 1m 52s	remaining: 1m 4s
# 635:	learn: 0.0583545	total: 1m 52s	remaining: 1m 4s
# 636:	learn: 0.0582973	total: 1m 52s	remaining: 1m 4s
# 637:	learn: 0.0581664	total: 1m 52s	remaining: 1m 3s
# 638:	learn: 0.0579693	total: 1m 52s	remaining: 1m 3s
# 639:	learn: 0.0573922	total: 1m 53s	remaining: 1m 3s
# 640:	learn: 0.0573825	total: 1m 53s	remaining: 1m 3s
# 641:	learn: 0.0573690	total: 1m 53s	remaining: 1m 3s
# 642:	learn: 0.0573587	total: 1m 53s	remaining: 1m 3s
# 643:	learn: 0.0572932	total: 1m 53s	remaining: 1m 2s
# 644:	learn: 0.0571191	total: 1m 54s	remaining: 1m 2s
# 645:	learn: 0.0571082	total: 1m 54s	remaining: 1m 2s
# 646:	learn: 0.0569971	total: 1m 54s	remaining: 1m 2s
# 647:	learn: 0.0569762	total: 1m 54s	remaining: 1m 2s
# 648:	learn: 0.0567301	total: 1m 54s	remaining: 1m 2s
# 649:	learn: 0.0567101	total: 1m 54s	remaining: 1m 1s
# 650:	learn: 0.0563817	total: 1m 55s	remaining: 1m 1s
# 651:	learn: 0.0563611	total: 1m 55s	remaining: 1m 1s
# 652:	learn: 0.0559722	total: 1m 55s	remaining: 1m 1s
# 653:	learn: 0.0559616	total: 1m 55s	remaining: 1m 1s
# 654:	learn: 0.0559360	total: 1m 55s	remaining: 1m 1s
# 655:	learn: 0.0555632	total: 1m 56s	remaining: 1m
# 656:	learn: 0.0554438	total: 1m 56s	remaining: 1m
# 657:	learn: 0.0554341	total: 1m 56s	remaining: 1m
# 658:	learn: 0.0547645	total: 1m 56s	remaining: 1m
# 659:	learn: 0.0547532	total: 1m 56s	remaining: 1m
# 660:	learn: 0.0547285	total: 1m 56s	remaining: 60s
# 661:	learn: 0.0547184	total: 1m 57s	remaining: 59.8s
# 662:	learn: 0.0543673	total: 1m 57s	remaining: 59.6s
# 663:	learn: 0.0543432	total: 1m 57s	remaining: 59.5s
# 664:	learn: 0.0543242	total: 1m 57s	remaining: 59.3s
# 665:	learn: 0.0540330	total: 1m 57s	remaining: 59.1s
# 666:	learn: 0.0540068	total: 1m 57s	remaining: 58.9s
# 667:	learn: 0.0539976	total: 1m 58s	remaining: 58.7s
# 668:	learn: 0.0535225	total: 1m 58s	remaining: 58.6s
# 669:	learn: 0.0535034	total: 1m 58s	remaining: 58.4s
# 670:	learn: 0.0534328	total: 1m 58s	remaining: 58.2s
# 671:	learn: 0.0532292	total: 1m 58s	remaining: 58s
# 672:	learn: 0.0532172	total: 1m 59s	remaining: 57.8s
# 673:	learn: 0.0531940	total: 1m 59s	remaining: 57.6s
# 674:	learn: 0.0531842	total: 1m 59s	remaining: 57.5s
# 675:	learn: 0.0530973	total: 1m 59s	remaining: 57.3s
# 676:	learn: 0.0530750	total: 1m 59s	remaining: 57.1s
# 677:	learn: 0.0525627	total: 1m 59s	remaining: 56.9s
# 678:	learn: 0.0525522	total: 2m	remaining: 56.7s
# 679:	learn: 0.0525426	total: 2m	remaining: 56.6s
# 680:	learn: 0.0525300	total: 2m	remaining: 56.4s
# 681:	learn: 0.0521610	total: 2m	remaining: 56.2s
# 682:	learn: 0.0521496	total: 2m	remaining: 56s
# 683:	learn: 0.0520215	total: 2m	remaining: 55.8s
# 684:	learn: 0.0520065	total: 2m 1s	remaining: 55.7s
# 685:	learn: 0.0519975	total: 2m 1s	remaining: 55.5s
# 686:	learn: 0.0519390	total: 2m 1s	remaining: 55.3s
# 687:	learn: 0.0519293	total: 2m 1s	remaining: 55.1s
# 688:	learn: 0.0514384	total: 2m 1s	remaining: 54.9s
# 689:	learn: 0.0510947	total: 2m 1s	remaining: 54.8s
# 690:	learn: 0.0510860	total: 2m 2s	remaining: 54.6s
# 691:	learn: 0.0510722	total: 2m 2s	remaining: 54.4s
# 692:	learn: 0.0507811	total: 2m 2s	remaining: 54.2s
# 693:	learn: 0.0507711	total: 2m 2s	remaining: 54s
# 694:	learn: 0.0507080	total: 2m 2s	remaining: 53.9s
# 695:	learn: 0.0503990	total: 2m 2s	remaining: 53.7s
# 696:	learn: 0.0499508	total: 2m 3s	remaining: 53.5s
# 697:	learn: 0.0499428	total: 2m 3s	remaining: 53.3s
# 698:	learn: 0.0498810	total: 2m 3s	remaining: 53.1s
# 699:	learn: 0.0498159	total: 2m 3s	remaining: 53s
# 700:	learn: 0.0498036	total: 2m 3s	remaining: 52.8s
# 701:	learn: 0.0492918	total: 2m 3s	remaining: 52.6s
# 702:	learn: 0.0492801	total: 2m 4s	remaining: 52.4s
# 703:	learn: 0.0491864	total: 2m 4s	remaining: 52.2s
# 704:	learn: 0.0488280	total: 2m 4s	remaining: 52.1s
# 705:	learn: 0.0488188	total: 2m 4s	remaining: 51.9s
# 706:	learn: 0.0487809	total: 2m 4s	remaining: 51.7s
# 707:	learn: 0.0487723	total: 2m 4s	remaining: 51.5s
# 708:	learn: 0.0487310	total: 2m 5s	remaining: 51.3s
# 709:	learn: 0.0487178	total: 2m 5s	remaining: 51.2s
# 710:	learn: 0.0484616	total: 2m 5s	remaining: 51s
# 711:	learn: 0.0484147	total: 2m 5s	remaining: 50.8s
# 712:	learn: 0.0484064	total: 2m 5s	remaining: 50.6s
# 713:	learn: 0.0480436	total: 2m 5s	remaining: 50.4s
# 714:	learn: 0.0480068	total: 2m 6s	remaining: 50.3s
# 715:	learn: 0.0479875	total: 2m 6s	remaining: 50.1s
# 716:	learn: 0.0478772	total: 2m 6s	remaining: 49.9s
# 717:	learn: 0.0478693	total: 2m 6s	remaining: 49.7s
# 718:	learn: 0.0473680	total: 2m 6s	remaining: 49.6s
# 719:	learn: 0.0473560	total: 2m 6s	remaining: 49.4s
# 720:	learn: 0.0473127	total: 2m 7s	remaining: 49.2s
# 721:	learn: 0.0472842	total: 2m 7s	remaining: 49s
# 722:	learn: 0.0472703	total: 2m 7s	remaining: 48.9s
# 723:	learn: 0.0472627	total: 2m 7s	remaining: 48.7s
# 724:	learn: 0.0472514	total: 2m 7s	remaining: 48.5s
# 725:	learn: 0.0472443	total: 2m 8s	remaining: 48.3s
# 726:	learn: 0.0470506	total: 2m 8s	remaining: 48.2s
# 727:	learn: 0.0470427	total: 2m 8s	remaining: 48s
# 728:	learn: 0.0470122	total: 2m 8s	remaining: 47.8s
# 729:	learn: 0.0469977	total: 2m 8s	remaining: 47.6s
# 730:	learn: 0.0469891	total: 2m 9s	remaining: 47.5s
# 731:	learn: 0.0469696	total: 2m 9s	remaining: 47.3s
# 732:	learn: 0.0465997	total: 2m 9s	remaining: 47.1s
# 733:	learn: 0.0465904	total: 2m 9s	remaining: 47s
# 734:	learn: 0.0465821	total: 2m 9s	remaining: 46.8s
# 735:	learn: 0.0464997	total: 2m 9s	remaining: 46.6s
# 736:	learn: 0.0464851	total: 2m 10s	remaining: 46.4s
# 737:	learn: 0.0464275	total: 2m 10s	remaining: 46.3s
# 738:	learn: 0.0464168	total: 2m 10s	remaining: 46.1s
# 739:	learn: 0.0460488	total: 2m 10s	remaining: 45.9s
# 740:	learn: 0.0460416	total: 2m 10s	remaining: 45.7s
# 741:	learn: 0.0457852	total: 2m 11s	remaining: 45.6s
# 742:	learn: 0.0457720	total: 2m 11s	remaining: 45.4s
# 743:	learn: 0.0457386	total: 2m 11s	remaining: 45.2s
# 744:	learn: 0.0457315	total: 2m 11s	remaining: 45s
# 745:	learn: 0.0451030	total: 2m 11s	remaining: 44.9s
# 746:	learn: 0.0450900	total: 2m 11s	remaining: 44.7s
# 747:	learn: 0.0450746	total: 2m 12s	remaining: 44.5s
# 748:	learn: 0.0448366	total: 2m 12s	remaining: 44.3s
# 749:	learn: 0.0448280	total: 2m 12s	remaining: 44.1s
# 750:	learn: 0.0447459	total: 2m 12s	remaining: 44s
# 751:	learn: 0.0447211	total: 2m 12s	remaining: 43.8s
# 752:	learn: 0.0443633	total: 2m 12s	remaining: 43.6s
# 753:	learn: 0.0443551	total: 2m 13s	remaining: 43.4s
# 754:	learn: 0.0443431	total: 2m 13s	remaining: 43.2s
# 755:	learn: 0.0443230	total: 2m 13s	remaining: 43.1s
# 756:	learn: 0.0442740	total: 2m 13s	remaining: 42.9s
# 757:	learn: 0.0442392	total: 2m 13s	remaining: 42.7s
# 758:	learn: 0.0440779	total: 2m 13s	remaining: 42.5s
# 759:	learn: 0.0440709	total: 2m 14s	remaining: 42.3s
# 760:	learn: 0.0440645	total: 2m 14s	remaining: 42.2s
# 761:	learn: 0.0440520	total: 2m 14s	remaining: 42s
# 762:	learn: 0.0440311	total: 2m 14s	remaining: 41.8s
# 763:	learn: 0.0440159	total: 2m 14s	remaining: 41.6s
# 764:	learn: 0.0440092	total: 2m 14s	remaining: 41.4s
# 765:	learn: 0.0439769	total: 2m 15s	remaining: 41.3s
# 766:	learn: 0.0437280	total: 2m 15s	remaining: 41.1s
# 767:	learn: 0.0437197	total: 2m 15s	remaining: 40.9s
# 768:	learn: 0.0432867	total: 2m 15s	remaining: 40.7s
# 769:	learn: 0.0432791	total: 2m 15s	remaining: 40.5s
# 770:	learn: 0.0430424	total: 2m 15s	remaining: 40.4s
# 771:	learn: 0.0430194	total: 2m 16s	remaining: 40.2s
# 772:	learn: 0.0430099	total: 2m 16s	remaining: 40s
# 773:	learn: 0.0429973	total: 2m 16s	remaining: 39.8s
# 774:	learn: 0.0426572	total: 2m 16s	remaining: 39.7s
# 775:	learn: 0.0426427	total: 2m 16s	remaining: 39.5s
# 776:	learn: 0.0424565	total: 2m 16s	remaining: 39.3s
# 777:	learn: 0.0424494	total: 2m 17s	remaining: 39.1s
# 778:	learn: 0.0422312	total: 2m 17s	remaining: 39s
# 779:	learn: 0.0422240	total: 2m 17s	remaining: 38.8s
# 780:	learn: 0.0422089	total: 2m 17s	remaining: 38.6s
# 781:	learn: 0.0419650	total: 2m 17s	remaining: 38.4s
# 964:	learn: 0.0292714	total: 2m 49s	remaining: 6.16s
# 965:	learn: 0.0292509	total: 2m 49s	remaining: 5.98s
# 966:	learn: 0.0291327	total: 2m 50s	remaining: 5.8s
# 967:	learn: 0.0291287	total: 2m 50s	remaining: 5.63s
# 968:	learn: 0.0291209	total: 2m 50s	remaining: 5.45s
# 969:	learn: 0.0291120	total: 2m 50s	remaining: 5.28s
# 970:	learn: 0.0291118	total: 2m 50s	remaining: 5.1s
# 971:	learn: 0.0290108	total: 2m 51s	remaining: 4.93s
# 972:	learn: 0.0290108	total: 2m 51s	remaining: 4.75s
# 973:	learn: 0.0289164	total: 2m 51s	remaining: 4.57s
# 974:	learn: 0.0289126	total: 2m 51s	remaining: 4.4s
# 975:	learn: 0.0289104	total: 2m 51s	remaining: 4.22s
# 976:	learn: 0.0288963	total: 2m 51s	remaining: 4.05s
# 977:	learn: 0.0288929	total: 2m 52s	remaining: 3.87s
# 978:	learn: 0.0286664	total: 2m 52s	remaining: 3.7s
# 979:	learn: 0.0284706	total: 2m 52s	remaining: 3.52s
# 980:	learn: 0.0284584	total: 2m 52s	remaining: 3.34s
# 981:	learn: 0.0281757	total: 2m 52s	remaining: 3.17s
# 982:	learn: 0.0281720	total: 2m 53s	remaining: 2.99s
# 983:	learn: 0.0281388	total: 2m 53s	remaining: 2.82s
# 984:	learn: 0.0281269	total: 2m 53s	remaining: 2.64s
# 985:	learn: 0.0281198	total: 2m 53s	remaining: 2.46s
# 986:	learn: 0.0278559	total: 2m 53s	remaining: 2.29s
# 987:	learn: 0.0278551	total: 2m 53s	remaining: 2.11s
# 988:	learn: 0.0278361	total: 2m 54s	remaining: 1.94s
# 989:	learn: 0.0278357	total: 2m 54s	remaining: 1.76s
# 990:	learn: 0.0278323	total: 2m 54s	remaining: 1.58s
# 991:	learn: 0.0278262	total: 2m 54s	remaining: 1.41s
# 992:	learn: 0.0277737	total: 2m 54s	remaining: 1.23s
# 993:	learn: 0.0277691	total: 2m 54s	remaining: 1.05s
# 994:	learn: 0.0277687	total: 2m 55s	remaining: 880ms
# 995:	learn: 0.0275403	total: 2m 55s	remaining: 704ms
# 996:	learn: 0.0275402	total: 2m 55s	remaining: 528ms
# 997:	learn: 0.0275401	total: 2m 55s	remaining: 352ms
# 998:	learn: 0.0273267	total: 2m 55s	remaining: 176ms
# 999:	learn: 0.0273236	total: 2m 55s	remaining: 0us

# %%
confusion_matrix = metrics.confusion_matrix(y_smote_test, y_smote_pred)

ax= plt.subplot()
sns.heatmap(confusion_matrix, annot=True, fmt='g', ax=ax);  #annot=True to annotate cells

# set labels snf title
ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')

plt.show()

# %%
print('Recall: {}'.format(confusion_matrix[1][1] / (confusion_matrix[1][1] + confusion_matrix[1][0])))
print('Precision: {}'.format(confusion_matrix[1][1] / (confusion_matrix[0][1] + confusion_matrix[1][1])))
print('Accuracy: {}'.format((confusion_matrix[0][0]+confusion_matrix[1][1]) / confusion_matrix.sum()))
# Out:
# Recall: 0.8354109855862875
# Precision: 0.8344357976653697
# Accuracy: 0.8348266458901441
