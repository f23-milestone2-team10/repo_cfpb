# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.2-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 18.1 MB/s eta 0:00:00
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.23.5)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.11.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2023.3.post1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (8.2.3)
# Installing collected packages: catboost
# Successfully installed catboost-1.2.2

# %%
# Built-in libraries
import re
import string
import warnings

# Third-party libraries for data handling and processing
import numpy as np
import pandas as pd
from nltk.corpus import stopwords
from tqdm import tqdm

# Feature extraction
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import KeyedVectors

# Pre-processing
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler, MaxAbsScaler
from imblearn.over_sampling import SMOTE

# Model selection and evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, classification_report

# Machine Learning Models
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier


# Deep Learning Libraries
from keras.models import Sequential
from keras.layers import Dense, Dropout, Conv1D, GlobalMaxPooling1D, LSTM
from keras.callbacks import EarlyStopping

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import altair as alt


# Miscellaneous
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
tqdm.pandas()
warnings.filterwarnings("ignore")


from google.colab import drive
drive.mount('/content/drive/')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# Mounted at /content/drive/

# %%
# files
file_path_01 = '/content/drive/My Drive/Colab Notebooks/assets/complaints.csv'

file_path_03 = '/content/drive/My Drive/Colab Notebooks/assets/GoogleNews-vectors-negative300.bin.gz'

# import DATA
DATA = pd.read_csv(file_path_01)

print(DATA.shape)
# Out:
# (4028530, 18)

# %%
# import word2vec model (this take a while to load)
word2vec = KeyedVectors.load_word2vec_format(file_path_03, binary=True)

# %%
# helper func: preprocess the narrative column

def preprocess_narrative(text):

    # Lowercase
    text = text.lower()

    # Remove XXXX like pattern
    text = re.sub(r'x{2,}', '', text)

    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))

    # Remove stopwords
    text = " ".join([word for word in text.split() if word not in stop_words])

    # Remove numbers
    text = re.sub(r'\d+', '', text)

    # Remove non-alphanumeric characters
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)

    # Remove extra spaces
    text = re.sub(r'\s+', ' ', text)

    # Remove leading and trailing spaces
    text = text.strip()

    return text

# %% [markdown]
# ### Approach: Mixture of categorical columns and TFIDF w2v matrix

# %%
DATA.columns
# Out:
# Index(['Date received', 'Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'ZIP code', 'Tags', 'Consumer consent provided?',
#        'Submitted via', 'Date sent to company', 'Company response to consumer',
#        'Timely response?', 'Consumer disputed?', 'Complaint ID'],
#       dtype='object')

# %%
dfm = DATA.copy()

# drop na on Consumer complaint narrative column, Consumer disputed? column
dfm.dropna(subset=['Consumer complaint narrative', 'Consumer disputed?'], inplace=True)

# drop Tags, ZIP code, Complaint ID, Timely response? columns
dfm.drop(['ZIP code', 'Complaint ID', 'Timely response?'], axis=1, inplace=True)

# dfm unique values
dfm.nunique()
# Out:
# Date received                      766
# Product                             12
# Sub-product                         46
# Issue                               91
# Sub-issue                           57
# Consumer complaint narrative    160940
# Company public response             10
# Company                           3148
# State                               62
# Tags                                 3
# Consumer consent provided?           1
# Submitted via                        1
# Date sent to company               862
# Company response to consumer         5
# Consumer disputed?                   2
# dtype: int64

# %%
# drop Consumer consent provided? column, submitted via column. no variance.

dfm.drop(['Consumer consent provided?', 'Submitted via'], axis=1, inplace=True)

dfm.nunique()
# Out:
# Date received                      766
# Product                             12
# Sub-product                         46
# Issue                               91
# Sub-issue                           57
# Consumer complaint narrative    160940
# Company public response             10
# Company                           3148
# State                               62
# Tags                                 3
# Date sent to company               862
# Company response to consumer         5
# Consumer disputed?                   2
# dtype: int64

# %%
# convert date received and date sent to company to datetime format, and compute date sent - date received, store in column 'days' as int

dfm['Date received'] = pd.to_datetime(dfm['Date received'])
dfm['Date sent to company'] = pd.to_datetime(dfm['Date sent to company'])

dfm['days'] = (dfm['Date sent to company'] - dfm['Date received']).dt.days

# drop Date received and Date sent to company columns
dfm.drop(['Date received', 'Date sent to company'], axis=1, inplace=True)
dfm.nunique()
# Out:
# Product                             12
# Sub-product                         46
# Issue                               91
# Sub-issue                           57
# Consumer complaint narrative    160940
# Company public response             10
# Company                           3148
# State                               62
# Tags                                 3
# Company response to consumer         5
# Consumer disputed?                   2
# days                               269
# dtype: int64

# %%
# fill na with 'Unknown' in all columns

dfm.fillna('Unknown', inplace=True)

dfm.isna().sum()
# Out:
# Product                         0
# Sub-product                     0
# Issue                           0
# Sub-issue                       0
# Consumer complaint narrative    0
# Company public response         0
# Company                         0
# State                           0
# Tags                            0
# Company response to consumer    0
# Consumer disputed?              0
# days                            0
# dtype: int64

# %%
# encode disputed column to 0 and 1

dfm['Consumer disputed?'] = dfm['Consumer disputed?'].map({'No': 0, 'Yes': 1})

dfm['Consumer disputed?'].value_counts()
# Out:
# 0    128227
# 1     35807
# Name: Consumer disputed?, dtype: int64

# %%
# preprocess narrative column and store in narrative_processed column

dfm['narrative_processed'] = dfm['Consumer complaint narrative'].progress_apply(preprocess_narrative)
# Out:
# 100%|██████████| 164034/164034 [00:16<00:00, 10068.13it/s]

# %%
# instantiate tfidf

tfidf = TfidfVectorizer()

# fit and transform tfidf vectorizer on narrative_processed column
tfidf.fit(dfm.narrative_processed)

# get tfidf feature names
tfidf_features = tfidf.get_feature_names_out()

# get tfidf weights
tfidf_weights = tfidf.idf_

# %%
# define a function get mean word2vec vector for a narrative

def get_mean_word2vec(narrative):

    # initialize vector
    vector = np.zeros(300)

    # get all words in narrative
    words = narrative.split()
    num_words = len(words)

    if num_words == 0:  # edge case: empty narrative
        return vector

    # calculate word vectors using list comprehension
    word_vectors = [word2vec[word] for word in words if word in word2vec]

    if word_vectors:
        vector = np.mean(word_vectors, axis=0)

    return vector


# define a function get mean tfidf weighted word2vec vector for a narrative
def get_mean_tfidf_weighted_word2vec(narrative):

    # initialize vector
    vector = np.zeros(300)

    # get all words in narrative
    words = narrative.split()
    num_words = len(words)

    if num_words == 0:  # edge case: empty narrative
        return vector

    # pre-calculate word-to-index mapping for tfidf_features for O(1) lookup
    word_to_index = {word: idx for idx, word in enumerate(tfidf_features)}

    # calculate word vectors using list comprehension
    word_vectors = [
        word2vec[word] * tfidf_weights[word_to_index[word]]
        for word in words if word in word2vec and word in word_to_index
    ]

    if word_vectors:
        vector = np.sum(word_vectors, axis=0) / num_words

    return vector

# %%
# compute mean tfidf weighted word2vec vector for each narrative (take a while)
dfm['narrative_tw'] = dfm['narrative_processed'].progress_apply(get_mean_tfidf_weighted_word2vec)

# convert dfm['narrative_tw']  to numpy array tw_array
tw_array = np.array(dfm.narrative_tw.tolist())

# print shape of tw_array
tw_array.shape
# Out:
# 100%|██████████| 164034/164034 [54:56<00:00, 49.77it/s]
# (164034, 300)

# %%
# copy target column to y
y = dfm['Consumer disputed?'].copy()

# %%
dfm.columns
# Out:
# Index(['Product', 'Sub-product', 'Issue', 'Sub-issue',
#        'Consumer complaint narrative', 'Company public response', 'Company',
#        'State', 'Tags', 'Company response to consumer', 'Consumer disputed?',
#        'days', 'narrative_processed', 'narrative_tw'],
#       dtype='object')

# %%
# drop Consumer complaint narrative, narrative_processed, Consumer disputed? columns

dfm.drop(['Consumer complaint narrative', 'narrative_processed', 'narrative_tw', 'Consumer disputed?'], axis=1, inplace=True)

# %%
dfm.nunique()
# Out:
# Product                           12
# Sub-product                       47
# Issue                             91
# Sub-issue                         58
# Company public response           11
# Company                         3148
# State                             63
# Tags                               4
# Company response to consumer       5
# days                             269
# dtype: int64

# %%
# one hot encode categorical columns

cats_cols = [
    'Product',
    'Sub-product',
    'Issue',
    'Sub-issue',
    'Company public response',
    'Company',
    'State',
    'Tags',
    'Company response to consumer',
]


dfm = pd.get_dummies(dfm, columns=cats_cols)

print(dfm.columns)

print(dfm.shape)
# Out:
# Index(['days', 'Product_Bank account or service', 'Product_Consumer Loan',
#        'Product_Credit card', 'Product_Credit reporting',
#        'Product_Debt collection', 'Product_Money transfers',
#        'Product_Mortgage', 'Product_Other financial service',
#        'Product_Payday loan',
#        ...
#        'State_WY', 'Tags_Older American', 'Tags_Older American, Servicemember',
#        'Tags_Servicemember', 'Tags_Unknown',
#        'Company response to consumer_Closed',
#        'Company response to consumer_Closed with explanation',
#        'Company response to consumer_Closed with monetary relief',
#        'Company response to consumer_Closed with non-monetary relief',
#        'Company response to consumer_Untimely response'],
#       dtype='object', length=3440)
# (164034, 3440)

# %%
# concatenate tw_array with dfm
X = np.concatenate((tw_array, dfm), axis=1)

# check shape of X
X.shape
# Out:
# (164034, 3740)

# %%
# smoote to oversample minority class
smote = SMOTE(random_state=42)
X_smote, y_smote = smote.fit_resample(X, y)

# print shape of X_smote, y_smote
print(X_smote.shape, y_smote.shape)
# Out:
# (256454, 3740) (256454,)

# %%
# train test split, 20% test, random_state=42, stratify=y_smote
X_smote_train, X_smote_test, y_smote_train, y_smote_test = train_test_split(X_smote, y_smote, stratify=y_smote, random_state=42, test_size=0.2)

# print shape
print(X_smote_train.shape, X_smote_test.shape, y_smote_train.shape, y_smote_test.shape)
# Out:
# (205163, 3740) (51291, 3740) (205163,) (51291,)

# %%
# train with logistic regression, wrap in a function

def train_lr(X_train, y_train, X_test, y_test):

    # instantiate logistic regression model
    lr = LogisticRegression(max_iter=1000, random_state=42).fit(X_train, y_train)

    # predict on test set
    y_pred = lr.predict(X_test)

    # print f1 score
    print(f"f1 score: {f1_score(y_test, y_pred)}")

    return lr


# train naive bayes

def train_naive_bayes(X_train, y_train, X_test, y_test):

    # instantiate naive bayes model
    nb = MultinomialNB()

    # fit model
    nb.fit(X_train, y_train)

    # predict on test set
    y_pred = nb.predict(X_test)

    # print f1 score
    print(f"f1 score: {f1_score(y_test, y_pred)}")

    return nb


# train lightgbm

def train_lgbm(X_train, y_train, X_test, y_test):

    # instantiate lightgbm model
    lgbm = LGBMClassifier(random_state=42).fit(X_train, y_train)

    # predict on test set
    y_pred = lgbm.predict(X_test)

    # print f1 score
    print(f"f1 score: {f1_score(y_test, y_pred)}")

    return lgbm


# train with xgboost

warnings.filterwarnings('ignore')
warnings.filterwarnings("ignore", message="Starting in XGBoost")

def train_xgb(X_train, y_train, X_test, y_test):

    # instantiate xgboost model
    xgb = XGBClassifier(random_state=42, n_jobs=-1)

    # fit model
    xgb.fit(X_train, y_train)

    # predict on test set
    y_pred = xgb.predict(X_test)

    # print f1 score
    print(f"f1 score: {f1_score(y_test, y_pred)}")

    return xgb


# catboost in a function

def train_catboost(X_train, y_train, X_test, y_test):

    # instantiate catboost model
    catboost = CatBoostClassifier(random_state=42)

    # fit model
    catboost.fit(X_train, y_train)

    # predict on test set
    y_pred = catboost.predict(X_test)

    # print accuracy score
    print(f"accuracy score: {accuracy_score(y_test, y_pred)}")

    # print f1 score
    print(f"f1 score: {f1_score(y_test, y_pred)}")

    return catboost


# train ann

def train_ann_tw_onehot(X_train, y_train, X_test, y_test):

    # instantiate ann model
    ann = Sequential()

    # add input layer
    ann.add(Dense(128, activation='relu', input_shape=(X_train.shape[1],)))

    # add hidden layers
    ann.add(Dense(64, activation='relu'))
    ann.add(Dense(32, activation='relu'))
    ann.add(Dense(16, activation='relu'))

    # add output layer
    ann.add(Dense(1, activation='sigmoid'))

    # compile model
    ann.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # fit model
    ann.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_test, y_test))

    # predict on test set
    y_pred = ann.predict(X_test)

    # print f1 score
    print(f"f1 score: {f1_score(y_test, y_pred.round())}")

    return ann

# %%
# train with logistic regression

model_lr = train_lr(X_smote_train, y_smote_train, X_smote_test, y_smote_test)
# Out:
# f1 score: 0.661993306061733

# %%
# train with naive bayes, scale values as nb not working with negative

min_max_scaler = MinMaxScaler()

model_nb = train_naive_bayes(min_max_scaler.fit_transform(X_smote_train), y_smote_train, min_max_scaler.transform(X_smote_test), y_smote_test)
# Out:
# f1 score: 0.6275373134328358

# %%
# train lightgbm

model_lgbm = train_lgbm(X_smote_train, y_smote_train, X_smote_test, y_smote_test)
# Out:
# [LightGBM] [Info] Number of positive: 102582, number of negative: 102581
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 1.170707 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 138687
# [LightGBM] [Info] Number of data points in the train set: 205163, number of used features: 1395
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500002 -> initscore=0.000010
# [LightGBM] [Info] Start training from score 0.000010
# f1 score: 0.8021170370052925

# %%
# train catboost

model_catboost = train_catboost(X_smote_train, y_smote_train, X_smote_test, y_smote_test)
# Out:
# Learning rate set to 0.100046
# 0:	learn: 0.6778634	total: 139ms	remaining: 2m 19s
# 1:	learn: 0.6672408	total: 224ms	remaining: 1m 51s
# 2:	learn: 0.6608011	total: 310ms	remaining: 1m 43s
# 3:	learn: 0.6471036	total: 396ms	remaining: 1m 38s
# 4:	learn: 0.6419977	total: 487ms	remaining: 1m 36s
# 5:	learn: 0.6374393	total: 569ms	remaining: 1m 34s
# 6:	learn: 0.6336227	total: 653ms	remaining: 1m 32s
# 7:	learn: 0.6178641	total: 735ms	remaining: 1m 31s
# 8:	learn: 0.6149668	total: 814ms	remaining: 1m 29s
# 9:	learn: 0.6082395	total: 899ms	remaining: 1m 28s
# 10:	learn: 0.6056475	total: 983ms	remaining: 1m 28s
# 11:	learn: 0.5951178	total: 1.06s	remaining: 1m 27s
# 12:	learn: 0.5926962	total: 1.15s	remaining: 1m 27s
# 13:	learn: 0.5868123	total: 1.24s	remaining: 1m 27s
# 14:	learn: 0.5848577	total: 1.32s	remaining: 1m 26s
# 15:	learn: 0.5829106	total: 1.4s	remaining: 1m 25s
# 16:	learn: 0.5812108	total: 1.47s	remaining: 1m 25s
# 17:	learn: 0.5772455	total: 1.55s	remaining: 1m 24s
# 18:	learn: 0.5755182	total: 1.63s	remaining: 1m 24s
# 19:	learn: 0.5710624	total: 1.71s	remaining: 1m 23s
# 20:	learn: 0.5696247	total: 1.78s	remaining: 1m 23s
# 21:	learn: 0.5683386	total: 1.86s	remaining: 1m 22s
# 22:	learn: 0.5668354	total: 1.93s	remaining: 1m 21s
# 23:	learn: 0.5626723	total: 2s	remaining: 1m 21s
# 24:	learn: 0.5564538	total: 2.09s	remaining: 1m 21s
# 25:	learn: 0.5539027	total: 2.17s	remaining: 1m 21s
# 26:	learn: 0.5459386	total: 2.24s	remaining: 1m 20s
# 27:	learn: 0.5447655	total: 2.31s	remaining: 1m 20s
# 28:	learn: 0.5339824	total: 2.38s	remaining: 1m 19s
# 29:	learn: 0.5329967	total: 2.46s	remaining: 1m 19s
# 30:	learn: 0.5214234	total: 2.53s	remaining: 1m 19s
# 31:	learn: 0.5197688	total: 2.6s	remaining: 1m 18s
# 32:	learn: 0.5171616	total: 2.68s	remaining: 1m 18s
# 33:	learn: 0.5163297	total: 2.75s	remaining: 1m 18s
# 34:	learn: 0.5153827	total: 2.83s	remaining: 1m 17s
# 35:	learn: 0.5138440	total: 2.9s	remaining: 1m 17s
# 36:	learn: 0.5130393	total: 2.97s	remaining: 1m 17s
# 37:	learn: 0.5123011	total: 3.05s	remaining: 1m 17s
# 38:	learn: 0.5085550	total: 3.12s	remaining: 1m 16s
# 39:	learn: 0.5063482	total: 3.19s	remaining: 1m 16s
# 40:	learn: 0.5032473	total: 3.26s	remaining: 1m 16s
# 41:	learn: 0.5001551	total: 3.33s	remaining: 1m 16s
# 42:	learn: 0.4984873	total: 3.41s	remaining: 1m 15s
# 43:	learn: 0.4978430	total: 3.48s	remaining: 1m 15s
# 44:	learn: 0.4972309	total: 3.56s	remaining: 1m 15s
# 45:	learn: 0.4950090	total: 3.63s	remaining: 1m 15s
# 46:	learn: 0.4923304	total: 3.71s	remaining: 1m 15s
# 47:	learn: 0.4911780	total: 3.78s	remaining: 1m 14s
# 48:	learn: 0.4859732	total: 3.84s	remaining: 1m 14s
# 49:	learn: 0.4854625	total: 3.92s	remaining: 1m 14s
# 50:	learn: 0.4849567	total: 4s	remaining: 1m 14s
# 51:	learn: 0.4844794	total: 4.07s	remaining: 1m 14s
# 52:	learn: 0.4808471	total: 4.15s	remaining: 1m 14s
# 53:	learn: 0.4798269	total: 4.22s	remaining: 1m 13s
# 54:	learn: 0.4788858	total: 4.29s	remaining: 1m 13s
# 55:	learn: 0.4784748	total: 4.36s	remaining: 1m 13s
# 56:	learn: 0.4761962	total: 4.44s	remaining: 1m 13s
# 57:	learn: 0.4755904	total: 4.51s	remaining: 1m 13s
# 58:	learn: 0.4725914	total: 4.59s	remaining: 1m 13s
# 59:	learn: 0.4714970	total: 4.66s	remaining: 1m 13s
# 60:	learn: 0.4695746	total: 4.73s	remaining: 1m 12s
# 61:	learn: 0.4687248	total: 4.8s	remaining: 1m 12s
# 62:	learn: 0.4677442	total: 4.88s	remaining: 1m 12s
# 63:	learn: 0.4653171	total: 4.95s	remaining: 1m 12s
# 64:	learn: 0.4637494	total: 5.02s	remaining: 1m 12s
# 65:	learn: 0.4624750	total: 5.11s	remaining: 1m 12s
# 66:	learn: 0.4621195	total: 5.18s	remaining: 1m 12s
# 67:	learn: 0.4600191	total: 5.25s	remaining: 1m 11s
# 68:	learn: 0.4593722	total: 5.32s	remaining: 1m 11s
# 69:	learn: 0.4590440	total: 5.41s	remaining: 1m 11s
# 70:	learn: 0.4576157	total: 5.48s	remaining: 1m 11s
# 71:	learn: 0.4566686	total: 5.54s	remaining: 1m 11s
# 72:	learn: 0.4556090	total: 5.62s	remaining: 1m 11s
# 73:	learn: 0.4543805	total: 5.69s	remaining: 1m 11s
# 74:	learn: 0.4533053	total: 5.75s	remaining: 1m 10s
# 75:	learn: 0.4530401	total: 5.82s	remaining: 1m 10s
# 76:	learn: 0.4524446	total: 5.89s	remaining: 1m 10s
# 77:	learn: 0.4520700	total: 5.96s	remaining: 1m 10s
# 78:	learn: 0.4513108	total: 6.02s	remaining: 1m 10s
# 79:	learn: 0.4510590	total: 6.1s	remaining: 1m 10s
# 80:	learn: 0.4492421	total: 6.16s	remaining: 1m 9s
# 81:	learn: 0.4489627	total: 6.24s	remaining: 1m 9s
# 82:	learn: 0.4485536	total: 6.3s	remaining: 1m 9s
# 83:	learn: 0.4483037	total: 6.38s	remaining: 1m 9s
# 84:	learn: 0.4473925	total: 6.45s	remaining: 1m 9s
# 85:	learn: 0.4471834	total: 6.52s	remaining: 1m 9s
# 86:	learn: 0.4458046	total: 6.59s	remaining: 1m 9s
# 87:	learn: 0.4441474	total: 6.68s	remaining: 1m 9s
# 88:	learn: 0.4435576	total: 6.75s	remaining: 1m 9s
# 89:	learn: 0.4432279	total: 6.82s	remaining: 1m 8s
# 90:	learn: 0.4425032	total: 6.89s	remaining: 1m 8s
# 91:	learn: 0.4422998	total: 6.96s	remaining: 1m 8s
# 92:	learn: 0.4412425	total: 7.03s	remaining: 1m 8s
# 93:	learn: 0.4407225	total: 7.1s	remaining: 1m 8s
# 94:	learn: 0.4392872	total: 7.17s	remaining: 1m 8s
# 95:	learn: 0.4381555	total: 7.25s	remaining: 1m 8s
# 96:	learn: 0.4379344	total: 7.32s	remaining: 1m 8s
# 97:	learn: 0.4371369	total: 7.38s	remaining: 1m 7s
# 98:	learn: 0.4369095	total: 7.46s	remaining: 1m 7s
# 99:	learn: 0.4366580	total: 7.53s	remaining: 1m 7s
# 100:	learn: 0.4360904	total: 7.6s	remaining: 1m 7s
# 101:	learn: 0.4347352	total: 7.67s	remaining: 1m 7s
# 102:	learn: 0.4343045	total: 7.73s	remaining: 1m 7s
# 103:	learn: 0.4341169	total: 7.82s	remaining: 1m 7s
# 104:	learn: 0.4337990	total: 7.9s	remaining: 1m 7s
# 105:	learn: 0.4328285	total: 7.98s	remaining: 1m 7s
# 106:	learn: 0.4316223	total: 8.06s	remaining: 1m 7s
# 107:	learn: 0.4313899	total: 8.15s	remaining: 1m 7s
# 108:	learn: 0.4310170	total: 8.23s	remaining: 1m 7s
# 109:	learn: 0.4303616	total: 8.32s	remaining: 1m 7s
# 110:	learn: 0.4295615	total: 8.39s	remaining: 1m 7s
# 111:	learn: 0.4290405	total: 8.48s	remaining: 1m 7s
# 112:	learn: 0.4287462	total: 8.55s	remaining: 1m 7s
# 113:	learn: 0.4283501	total: 8.63s	remaining: 1m 7s
# 114:	learn: 0.4272955	total: 8.71s	remaining: 1m 7s
# 115:	learn: 0.4270067	total: 8.78s	remaining: 1m 6s
# 116:	learn: 0.4268309	total: 8.86s	remaining: 1m 6s
# 117:	learn: 0.4259782	total: 8.94s	remaining: 1m 6s
# 118:	learn: 0.4255794	total: 9.02s	remaining: 1m 6s
# 119:	learn: 0.4249235	total: 9.12s	remaining: 1m 6s
# 120:	learn: 0.4247284	total: 9.2s	remaining: 1m 6s
# 121:	learn: 0.4242240	total: 9.28s	remaining: 1m 6s
# 122:	learn: 0.4240605	total: 9.36s	remaining: 1m 6s
# 123:	learn: 0.4231444	total: 9.44s	remaining: 1m 6s
# 124:	learn: 0.4224214	total: 9.51s	remaining: 1m 6s
# 125:	learn: 0.4219980	total: 9.6s	remaining: 1m 6s
# 126:	learn: 0.4218403	total: 9.69s	remaining: 1m 6s
# 127:	learn: 0.4216378	total: 9.78s	remaining: 1m 6s
# 128:	learn: 0.4211931	total: 9.85s	remaining: 1m 6s
# 129:	learn: 0.4210544	total: 9.94s	remaining: 1m 6s
# 130:	learn: 0.4208257	total: 10s	remaining: 1m 6s
# 131:	learn: 0.4204765	total: 10.1s	remaining: 1m 6s
# 132:	learn: 0.4197471	total: 10.2s	remaining: 1m 6s
# 133:	learn: 0.4192144	total: 10.3s	remaining: 1m 6s
# 134:	learn: 0.4189208	total: 10.3s	remaining: 1m 6s
# 135:	learn: 0.4183861	total: 10.4s	remaining: 1m 6s
# 136:	learn: 0.4178371	total: 10.5s	remaining: 1m 5s
# 137:	learn: 0.4164648	total: 10.5s	remaining: 1m 5s
# 138:	learn: 0.4153431	total: 10.6s	remaining: 1m 5s
# 139:	learn: 0.4151416	total: 10.7s	remaining: 1m 5s
# 140:	learn: 0.4149307	total: 10.8s	remaining: 1m 5s
# 141:	learn: 0.4144791	total: 10.9s	remaining: 1m 5s
# 142:	learn: 0.4142660	total: 11s	remaining: 1m 5s
# 143:	learn: 0.4135204	total: 11s	remaining: 1m 5s
# 144:	learn: 0.4131121	total: 11.1s	remaining: 1m 5s
# 145:	learn: 0.4129276	total: 11.2s	remaining: 1m 5s
# 146:	learn: 0.4123720	total: 11.3s	remaining: 1m 5s
# 147:	learn: 0.4121907	total: 11.3s	remaining: 1m 5s
# 148:	learn: 0.4115785	total: 11.4s	remaining: 1m 5s
# 149:	learn: 0.4112709	total: 11.5s	remaining: 1m 5s
# 150:	learn: 0.4110364	total: 11.5s	remaining: 1m 4s
# 151:	learn: 0.4108401	total: 11.6s	remaining: 1m 4s
# 152:	learn: 0.4104708	total: 11.7s	remaining: 1m 4s
# 153:	learn: 0.4099225	total: 11.8s	remaining: 1m 4s
# 154:	learn: 0.4097608	total: 11.8s	remaining: 1m 4s
# 155:	learn: 0.4094032	total: 11.9s	remaining: 1m 4s
# 156:	learn: 0.4092280	total: 12s	remaining: 1m 4s
# 157:	learn: 0.4088416	total: 12.1s	remaining: 1m 4s
# 158:	learn: 0.4084270	total: 12.1s	remaining: 1m 4s
# 159:	learn: 0.4082815	total: 12.2s	remaining: 1m 4s
# 160:	learn: 0.4079905	total: 12.3s	remaining: 1m 4s
# 161:	learn: 0.4073918	total: 12.3s	remaining: 1m 3s
# 162:	learn: 0.4067653	total: 12.4s	remaining: 1m 3s
# 163:	learn: 0.4058238	total: 12.5s	remaining: 1m 3s
# 164:	learn: 0.4056692	total: 12.6s	remaining: 1m 3s
# 165:	learn: 0.4055006	total: 12.7s	remaining: 1m 3s
# 166:	learn: 0.4053472	total: 12.7s	remaining: 1m 3s
# 167:	learn: 0.4050598	total: 12.8s	remaining: 1m 3s
# 168:	learn: 0.4049008	total: 12.9s	remaining: 1m 3s
# 169:	learn: 0.4046875	total: 12.9s	remaining: 1m 3s
# 170:	learn: 0.4041609	total: 13s	remaining: 1m 3s
# 171:	learn: 0.4036765	total: 13.1s	remaining: 1m 2s
# 172:	learn: 0.4035015	total: 13.2s	remaining: 1m 2s
# 173:	learn: 0.4033575	total: 13.2s	remaining: 1m 2s
# 174:	learn: 0.4032114	total: 13.3s	remaining: 1m 2s
# 175:	learn: 0.4029311	total: 13.4s	remaining: 1m 2s
# 176:	learn: 0.4027887	total: 13.5s	remaining: 1m 2s
# 177:	learn: 0.4026356	total: 13.5s	remaining: 1m 2s
# 178:	learn: 0.4023303	total: 13.6s	remaining: 1m 2s
# 179:	learn: 0.4021662	total: 13.7s	remaining: 1m 2s
# 180:	learn: 0.4020290	total: 13.7s	remaining: 1m 2s
# 181:	learn: 0.4018193	total: 13.8s	remaining: 1m 2s
# 182:	learn: 0.4017100	total: 13.9s	remaining: 1m 1s
# 183:	learn: 0.4012772	total: 14s	remaining: 1m 1s
# 184:	learn: 0.4011119	total: 14s	remaining: 1m 1s
# 185:	learn: 0.4007274	total: 14.1s	remaining: 1m 1s
# 186:	learn: 0.4005972	total: 14.2s	remaining: 1m 1s
# 187:	learn: 0.4004044	total: 14.3s	remaining: 1m 1s
# 188:	learn: 0.4002790	total: 14.3s	remaining: 1m 1s
# 189:	learn: 0.3996788	total: 14.4s	remaining: 1m 1s
# 190:	learn: 0.3991928	total: 14.5s	remaining: 1m 1s
# 191:	learn: 0.3990004	total: 14.5s	remaining: 1m 1s
# 192:	learn: 0.3987261	total: 14.6s	remaining: 1m 1s
# 193:	learn: 0.3985736	total: 14.7s	remaining: 1m
# 194:	learn: 0.3984547	total: 14.8s	remaining: 1m
# 195:	learn: 0.3982846	total: 14.8s	remaining: 1m
# 196:	learn: 0.3981404	total: 14.9s	remaining: 1m
# 197:	learn: 0.3976486	total: 15s	remaining: 1m
# 198:	learn: 0.3971898	total: 15.1s	remaining: 1m
# 199:	learn: 0.3969193	total: 15.1s	remaining: 1m
# 200:	learn: 0.3965885	total: 15.2s	remaining: 1m
# 201:	learn: 0.3964313	total: 15.3s	remaining: 1m
# 202:	learn: 0.3963040	total: 15.4s	remaining: 1m
# 203:	learn: 0.3961787	total: 15.4s	remaining: 1m
# 204:	learn: 0.3960530	total: 15.5s	remaining: 1m
# 205:	learn: 0.3957150	total: 15.6s	remaining: 1m
# 206:	learn: 0.3955522	total: 15.7s	remaining: 60s
# 207:	learn: 0.3954284	total: 15.7s	remaining: 59.9s
# 208:	learn: 0.3952624	total: 15.8s	remaining: 59.8s
# 209:	learn: 0.3951396	total: 15.9s	remaining: 59.7s
# 210:	learn: 0.3947697	total: 15.9s	remaining: 59.6s
# 211:	learn: 0.3942519	total: 16s	remaining: 59.5s
# 212:	learn: 0.3940293	total: 16.1s	remaining: 59.4s
# 213:	learn: 0.3935474	total: 16.2s	remaining: 59.3s
# 214:	learn: 0.3930709	total: 16.2s	remaining: 59.2s
# 215:	learn: 0.3929393	total: 16.3s	remaining: 59.2s
# 216:	learn: 0.3928037	total: 16.4s	remaining: 59.1s
# 217:	learn: 0.3926646	total: 16.5s	remaining: 59.1s
# 218:	learn: 0.3925538	total: 16.6s	remaining: 59s
# 219:	learn: 0.3924045	total: 16.6s	remaining: 59s
# 220:	learn: 0.3920465	total: 16.7s	remaining: 59s
# 221:	learn: 0.3919278	total: 16.8s	remaining: 58.9s
# 222:	learn: 0.3918114	total: 16.9s	remaining: 58.8s
# 223:	learn: 0.3916959	total: 16.9s	remaining: 58.7s
# 224:	learn: 0.3915226	total: 17s	remaining: 58.6s
# 225:	learn: 0.3914045	total: 17.1s	remaining: 58.5s
# 226:	learn: 0.3912802	total: 17.2s	remaining: 58.5s
# 227:	learn: 0.3907800	total: 17.2s	remaining: 58.4s
# 228:	learn: 0.3906627	total: 17.3s	remaining: 58.3s
# 229:	learn: 0.3905465	total: 17.4s	remaining: 58.2s
# 230:	learn: 0.3904309	total: 17.5s	remaining: 58.2s
# 231:	learn: 0.3903404	total: 17.5s	remaining: 58.1s
# 232:	learn: 0.3899290	total: 17.6s	remaining: 58s
# 233:	learn: 0.3898088	total: 17.7s	remaining: 58s
# 234:	learn: 0.3895090	total: 17.8s	remaining: 57.9s
# 235:	learn: 0.3890877	total: 17.8s	remaining: 57.8s
# 236:	learn: 0.3880803	total: 17.9s	remaining: 57.7s
# 237:	learn: 0.3879340	total: 18s	remaining: 57.6s
# 238:	learn: 0.3878049	total: 18.1s	remaining: 57.6s
# 239:	learn: 0.3876915	total: 18.2s	remaining: 57.5s
# 240:	learn: 0.3874143	total: 18.2s	remaining: 57.4s
# 241:	learn: 0.3871847	total: 18.3s	remaining: 57.3s
# 242:	learn: 0.3870515	total: 18.4s	remaining: 57.2s
# 243:	learn: 0.3869369	total: 18.5s	remaining: 57.2s
# 244:	learn: 0.3867974	total: 18.6s	remaining: 57.2s
# 245:	learn: 0.3866872	total: 18.6s	remaining: 57.1s
# 246:	learn: 0.3863980	total: 18.7s	remaining: 57s
# 247:	learn: 0.3862869	total: 18.8s	remaining: 57s
# 248:	learn: 0.3861514	total: 18.9s	remaining: 56.9s
# 249:	learn: 0.3860357	total: 19s	remaining: 56.9s
# 250:	learn: 0.3857172	total: 19s	remaining: 56.8s
# 251:	learn: 0.3855905	total: 19.1s	remaining: 56.8s
# 252:	learn: 0.3854859	total: 19.2s	remaining: 56.7s
# 253:	learn: 0.3853586	total: 19.3s	remaining: 56.6s
# 254:	learn: 0.3852651	total: 19.4s	remaining: 56.6s
# 255:	learn: 0.3851529	total: 19.5s	remaining: 56.6s
# 256:	learn: 0.3850469	total: 19.5s	remaining: 56.5s
# 257:	learn: 0.3847772	total: 19.6s	remaining: 56.4s
# 258:	learn: 0.3846520	total: 19.7s	remaining: 56.4s
# 259:	learn: 0.3845432	total: 19.8s	remaining: 56.3s
# 260:	learn: 0.3844004	total: 19.9s	remaining: 56.3s
# 261:	learn: 0.3842708	total: 20s	remaining: 56.3s
# 262:	learn: 0.3841454	total: 20.1s	remaining: 56.2s
# 263:	learn: 0.3840244	total: 20.1s	remaining: 56.1s
# 264:	learn: 0.3838407	total: 20.2s	remaining: 56.1s
# 265:	learn: 0.3835699	total: 20.3s	remaining: 56s
# 266:	learn: 0.3834609	total: 20.4s	remaining: 55.9s
# 267:	learn: 0.3833341	total: 20.4s	remaining: 55.8s
# 268:	learn: 0.3832151	total: 20.5s	remaining: 55.8s
# 269:	learn: 0.3831187	total: 20.6s	remaining: 55.7s
# 270:	learn: 0.3829759	total: 20.7s	remaining: 55.6s
# 271:	learn: 0.3828641	total: 20.7s	remaining: 55.5s
# 272:	learn: 0.3827754	total: 20.8s	remaining: 55.4s
# 273:	learn: 0.3825622	total: 20.9s	remaining: 55.3s
# 274:	learn: 0.3824774	total: 21s	remaining: 55.3s
# 275:	learn: 0.3823735	total: 21s	remaining: 55.1s
# 276:	learn: 0.3822672	total: 21.1s	remaining: 55.1s
# 277:	learn: 0.3821567	total: 21.2s	remaining: 55s
# 278:	learn: 0.3820544	total: 21.3s	remaining: 54.9s
# 279:	learn: 0.3818451	total: 21.3s	remaining: 54.8s
# 280:	learn: 0.3817318	total: 21.4s	remaining: 54.8s
# 281:	learn: 0.3816262	total: 21.5s	remaining: 54.7s
# 282:	learn: 0.3815424	total: 21.6s	remaining: 54.7s
# 283:	learn: 0.3814344	total: 21.7s	remaining: 54.6s
# 284:	learn: 0.3813089	total: 21.7s	remaining: 54.5s
# 285:	learn: 0.3812045	total: 21.8s	remaining: 54.5s
# 286:	learn: 0.3810257	total: 21.9s	remaining: 54.5s
# 287:	learn: 0.3809302	total: 22s	remaining: 54.4s
# 288:	learn: 0.3808256	total: 22.1s	remaining: 54.3s
# 289:	learn: 0.3805718	total: 22.2s	remaining: 54.3s
# 290:	learn: 0.3803658	total: 22.2s	remaining: 54.2s
# 291:	learn: 0.3802435	total: 22.3s	remaining: 54.1s
# 292:	learn: 0.3801565	total: 22.4s	remaining: 54s
# 293:	learn: 0.3800689	total: 22.5s	remaining: 54s
# 294:	learn: 0.3799689	total: 22.6s	remaining: 53.9s
# 295:	learn: 0.3798790	total: 22.7s	remaining: 53.9s
# 296:	learn: 0.3796996	total: 22.7s	remaining: 53.8s
# 297:	learn: 0.3795023	total: 22.8s	remaining: 53.7s
# 298:	learn: 0.3794015	total: 22.9s	remaining: 53.7s
# 299:	learn: 0.3793227	total: 23s	remaining: 53.6s
# 300:	learn: 0.3792061	total: 23s	remaining: 53.5s
# 301:	learn: 0.3791250	total: 23.1s	remaining: 53.4s
# 302:	learn: 0.3790318	total: 23.2s	remaining: 53.4s
# 303:	learn: 0.3789283	total: 23.3s	remaining: 53.3s
# 304:	learn: 0.3788586	total: 23.4s	remaining: 53.2s
# 305:	learn: 0.3787589	total: 23.4s	remaining: 53.2s
# 306:	learn: 0.3785634	total: 23.5s	remaining: 53.1s
# 307:	learn: 0.3784673	total: 23.6s	remaining: 53s
# 308:	learn: 0.3783625	total: 23.7s	remaining: 53s
# 309:	learn: 0.3782607	total: 23.8s	remaining: 52.9s
# 310:	learn: 0.3781636	total: 23.8s	remaining: 52.8s
# 311:	learn: 0.3778513	total: 23.9s	remaining: 52.8s
# 312:	learn: 0.3777479	total: 24s	remaining: 52.7s
# 313:	learn: 0.3776865	total: 24.1s	remaining: 52.6s
# 314:	learn: 0.3774891	total: 24.2s	remaining: 52.5s
# 315:	learn: 0.3772623	total: 24.2s	remaining: 52.5s
# 316:	learn: 0.3771673	total: 24.3s	remaining: 52.4s
# 317:	learn: 0.3770712	total: 24.4s	remaining: 52.4s
# 318:	learn: 0.3769352	total: 24.5s	remaining: 52.3s
# 319:	learn: 0.3768575	total: 24.6s	remaining: 52.2s
# 320:	learn: 0.3767561	total: 24.7s	remaining: 52.2s
# 321:	learn: 0.3766092	total: 24.7s	remaining: 52.1s
# 322:	learn: 0.3764907	total: 24.8s	remaining: 52s
# 323:	learn: 0.3764164	total: 24.9s	remaining: 51.9s
# 324:	learn: 0.3762581	total: 25s	remaining: 51.9s
# 325:	learn: 0.3761718	total: 25s	remaining: 51.8s
# 326:	learn: 0.3760566	total: 25.1s	remaining: 51.7s
# 327:	learn: 0.3759889	total: 25.2s	remaining: 51.6s
# 328:	learn: 0.3759032	total: 25.3s	remaining: 51.5s
# 329:	learn: 0.3758170	total: 25.3s	remaining: 51.5s
# 330:	learn: 0.3757415	total: 25.4s	remaining: 51.4s
# 331:	learn: 0.3756381	total: 25.5s	remaining: 51.3s
# 332:	learn: 0.3755334	total: 25.6s	remaining: 51.2s
# 333:	learn: 0.3754216	total: 25.6s	remaining: 51.1s
# 334:	learn: 0.3751958	total: 25.7s	remaining: 51.1s
# 335:	learn: 0.3750860	total: 25.8s	remaining: 51s
# 336:	learn: 0.3750006	total: 25.9s	remaining: 50.9s
# 337:	learn: 0.3749083	total: 26s	remaining: 50.8s
# 338:	learn: 0.3740256	total: 26s	remaining: 50.8s
# 339:	learn: 0.3739040	total: 26.1s	remaining: 50.7s
# 340:	learn: 0.3737584	total: 26.2s	remaining: 50.6s
# 341:	learn: 0.3736545	total: 26.3s	remaining: 50.5s
# 342:	learn: 0.3735572	total: 26.3s	remaining: 50.5s
# 343:	learn: 0.3734424	total: 26.4s	remaining: 50.4s
# 344:	learn: 0.3733551	total: 26.5s	remaining: 50.3s
# 345:	learn: 0.3732298	total: 26.6s	remaining: 50.2s
# 346:	learn: 0.3731157	total: 26.7s	remaining: 50.2s
# 347:	learn: 0.3730501	total: 26.7s	remaining: 50.1s
# 348:	learn: 0.3729649	total: 26.8s	remaining: 50s
# 349:	learn: 0.3728450	total: 26.9s	remaining: 49.9s
# 350:	learn: 0.3722959	total: 27s	remaining: 49.8s
# 351:	learn: 0.3721983	total: 27s	remaining: 49.8s
# 352:	learn: 0.3721158	total: 27.1s	remaining: 49.7s
# 353:	learn: 0.3720210	total: 27.2s	remaining: 49.6s
# 354:	learn: 0.3719243	total: 27.3s	remaining: 49.5s
# 355:	learn: 0.3718536	total: 27.3s	remaining: 49.4s
# 356:	learn: 0.3717536	total: 27.4s	remaining: 49.4s
# 357:	learn: 0.3716807	total: 27.5s	remaining: 49.3s
# 358:	learn: 0.3716030	total: 27.6s	remaining: 49.2s
# 359:	learn: 0.3715411	total: 27.6s	remaining: 49.1s
# 360:	learn: 0.3714496	total: 27.7s	remaining: 49.1s
# 361:	learn: 0.3712625	total: 27.8s	remaining: 49s
# 362:	learn: 0.3711766	total: 27.9s	remaining: 48.9s
# 363:	learn: 0.3706448	total: 27.9s	remaining: 48.8s
# 364:	learn: 0.3705560	total: 28s	remaining: 48.7s
# 365:	learn: 0.3704434	total: 28.1s	remaining: 48.7s
# 366:	learn: 0.3703493	total: 28.2s	remaining: 48.6s
# 367:	learn: 0.3702794	total: 28.2s	remaining: 48.5s
# 368:	learn: 0.3701916	total: 28.3s	remaining: 48.4s
# 369:	learn: 0.3701110	total: 28.4s	remaining: 48.3s
# 370:	learn: 0.3700197	total: 28.5s	remaining: 48.3s
# 371:	learn: 0.3699339	total: 28.5s	remaining: 48.2s
# 372:	learn: 0.3698521	total: 28.6s	remaining: 48.1s
# 373:	learn: 0.3697519	total: 28.7s	remaining: 48s
# 374:	learn: 0.3696707	total: 28.8s	remaining: 48s
# 375:	learn: 0.3695843	total: 28.8s	remaining: 47.9s
# 376:	learn: 0.3695037	total: 28.9s	remaining: 47.8s
# 377:	learn: 0.3693956	total: 29s	remaining: 47.7s
# 378:	learn: 0.3693113	total: 29.1s	remaining: 47.6s
# 379:	learn: 0.3691285	total: 29.2s	remaining: 47.6s
# 380:	learn: 0.3690487	total: 29.2s	remaining: 47.5s
# 381:	learn: 0.3689505	total: 29.3s	remaining: 47.4s
# 382:	learn: 0.3688649	total: 29.4s	remaining: 47.4s
# 383:	learn: 0.3686175	total: 29.5s	remaining: 47.3s
# 384:	learn: 0.3683510	total: 29.5s	remaining: 47.2s
# 385:	learn: 0.3682678	total: 29.6s	remaining: 47.1s
# 386:	learn: 0.3681824	total: 29.7s	remaining: 47s
# 387:	learn: 0.3681015	total: 29.8s	remaining: 46.9s
# 388:	learn: 0.3680177	total: 29.8s	remaining: 46.9s
# 389:	learn: 0.3676862	total: 29.9s	remaining: 46.8s
# 390:	learn: 0.3675682	total: 30s	remaining: 46.7s
# 391:	learn: 0.3674877	total: 30.1s	remaining: 46.6s
# 392:	learn: 0.3673911	total: 30.1s	remaining: 46.5s
# 393:	learn: 0.3673185	total: 30.2s	remaining: 46.5s
# 394:	learn: 0.3672572	total: 30.3s	remaining: 46.4s
# 395:	learn: 0.3671725	total: 30.3s	remaining: 46.3s
# 396:	learn: 0.3670687	total: 30.4s	remaining: 46.2s
# 397:	learn: 0.3669846	total: 30.5s	remaining: 46.1s
# 398:	learn: 0.3668935	total: 30.6s	remaining: 46.1s
# 399:	learn: 0.3668095	total: 30.7s	remaining: 46s
# 400:	learn: 0.3667060	total: 30.8s	remaining: 45.9s
# 401:	learn: 0.3666306	total: 30.8s	remaining: 45.9s
# 402:	learn: 0.3664928	total: 30.9s	remaining: 45.8s
# 403:	learn: 0.3661440	total: 31s	remaining: 45.7s
# 404:	learn: 0.3660560	total: 31.1s	remaining: 45.6s
# 405:	learn: 0.3659425	total: 31.2s	remaining: 45.6s
# 406:	learn: 0.3658575	total: 31.2s	remaining: 45.5s
# 407:	learn: 0.3655869	total: 31.3s	remaining: 45.4s
# 408:	learn: 0.3654775	total: 31.4s	remaining: 45.4s
# 409:	learn: 0.3654028	total: 31.5s	remaining: 45.3s
# 410:	learn: 0.3653536	total: 31.5s	remaining: 45.2s
# 411:	learn: 0.3652366	total: 31.6s	remaining: 45.1s
# 412:	learn: 0.3650723	total: 31.7s	remaining: 45s
# 413:	learn: 0.3649927	total: 31.8s	remaining: 45s
# 414:	learn: 0.3649109	total: 31.9s	remaining: 44.9s
# 415:	learn: 0.3648219	total: 31.9s	remaining: 44.8s
# 416:	learn: 0.3646496	total: 32s	remaining: 44.8s
# 417:	learn: 0.3645766	total: 32.1s	remaining: 44.7s
# 418:	learn: 0.3644873	total: 32.2s	remaining: 44.6s
# 419:	learn: 0.3643328	total: 32.2s	remaining: 44.5s
# 420:	learn: 0.3642427	total: 32.3s	remaining: 44.5s
# 421:	learn: 0.3641709	total: 32.4s	remaining: 44.4s
# 422:	learn: 0.3641136	total: 32.5s	remaining: 44.3s
# 423:	learn: 0.3640396	total: 32.5s	remaining: 44.2s
# 424:	learn: 0.3637895	total: 32.6s	remaining: 44.1s
# 425:	learn: 0.3636951	total: 32.7s	remaining: 44.1s
# 426:	learn: 0.3636050	total: 32.8s	remaining: 44s
# 427:	learn: 0.3635145	total: 32.9s	remaining: 43.9s
# 428:	learn: 0.3634204	total: 32.9s	remaining: 43.9s
# 429:	learn: 0.3633604	total: 33s	remaining: 43.8s
# 430:	learn: 0.3632882	total: 33.1s	remaining: 43.7s
# 431:	learn: 0.3632001	total: 33.2s	remaining: 43.6s
# 432:	learn: 0.3631059	total: 33.2s	remaining: 43.5s
# 433:	learn: 0.3629063	total: 33.3s	remaining: 43.5s
# 434:	learn: 0.3628350	total: 33.4s	remaining: 43.4s
# 435:	learn: 0.3627327	total: 33.5s	remaining: 43.3s
# 436:	learn: 0.3626503	total: 33.6s	remaining: 43.2s
# 437:	learn: 0.3625587	total: 33.6s	remaining: 43.1s
# 438:	learn: 0.3624786	total: 33.7s	remaining: 43.1s
# 439:	learn: 0.3621726	total: 33.8s	remaining: 43s
# 440:	learn: 0.3620926	total: 33.8s	remaining: 42.9s
# 441:	learn: 0.3620003	total: 33.9s	remaining: 42.8s
# 442:	learn: 0.3619152	total: 34s	remaining: 42.8s
# 443:	learn: 0.3618212	total: 34.1s	remaining: 42.7s
# 444:	learn: 0.3617281	total: 34.2s	remaining: 42.6s
# 445:	learn: 0.3616525	total: 34.2s	remaining: 42.5s
# 446:	learn: 0.3615838	total: 34.3s	remaining: 42.5s
# 447:	learn: 0.3614130	total: 34.4s	remaining: 42.4s
# 448:	learn: 0.3613129	total: 34.5s	remaining: 42.3s
# 449:	learn: 0.3612326	total: 34.6s	remaining: 42.2s
# 450:	learn: 0.3611411	total: 34.6s	remaining: 42.2s
# 451:	learn: 0.3610351	total: 34.7s	remaining: 42.1s
# 452:	learn: 0.3609491	total: 34.8s	remaining: 42s
# 453:	learn: 0.3607057	total: 34.9s	remaining: 41.9s
# 454:	learn: 0.3606143	total: 35s	remaining: 41.9s
# 455:	learn: 0.3605945	total: 35s	remaining: 41.8s
# 456:	learn: 0.3604427	total: 35.1s	remaining: 41.7s
# 457:	learn: 0.3602936	total: 35.2s	remaining: 41.7s
# 458:	learn: 0.3601647	total: 35.3s	remaining: 41.6s
# 459:	learn: 0.3600957	total: 35.4s	remaining: 41.5s
# 460:	learn: 0.3600109	total: 35.5s	remaining: 41.4s
# 461:	learn: 0.3599074	total: 35.5s	remaining: 41.4s
# 462:	learn: 0.3598196	total: 35.6s	remaining: 41.3s
# 463:	learn: 0.3597398	total: 35.7s	remaining: 41.3s
# 464:	learn: 0.3596558	total: 35.8s	remaining: 41.2s
# 465:	learn: 0.3595742	total: 35.9s	remaining: 41.1s
# 466:	learn: 0.3594210	total: 36s	remaining: 41s
# 467:	learn: 0.3593048	total: 36s	remaining: 41s
# 468:	learn: 0.3592102	total: 36.1s	remaining: 40.9s
# 469:	learn: 0.3590602	total: 36.2s	remaining: 40.8s
# 470:	learn: 0.3589521	total: 36.3s	remaining: 40.7s
# 471:	learn: 0.3588738	total: 36.4s	remaining: 40.7s
# 472:	learn: 0.3588479	total: 36.4s	remaining: 40.6s
# 473:	learn: 0.3587659	total: 36.5s	remaining: 40.5s
# 474:	learn: 0.3587530	total: 36.6s	remaining: 40.4s
# 475:	learn: 0.3586869	total: 36.7s	remaining: 40.4s
# 476:	learn: 0.3586242	total: 36.7s	remaining: 40.3s
# 477:	learn: 0.3585532	total: 36.8s	remaining: 40.2s
# 478:	learn: 0.3584806	total: 36.9s	remaining: 40.1s
# 479:	learn: 0.3583803	total: 37s	remaining: 40.1s
# 480:	learn: 0.3582941	total: 37.1s	remaining: 40s
# 481:	learn: 0.3582333	total: 37.2s	remaining: 39.9s
# 482:	learn: 0.3581579	total: 37.2s	remaining: 39.9s
# 483:	learn: 0.3580924	total: 37.3s	remaining: 39.8s
# 484:	learn: 0.3580187	total: 37.4s	remaining: 39.7s
# 485:	learn: 0.3579402	total: 37.5s	remaining: 39.7s
# 486:	learn: 0.3578638	total: 37.6s	remaining: 39.6s
# 487:	learn: 0.3577658	total: 37.7s	remaining: 39.5s
# 488:	learn: 0.3576612	total: 37.8s	remaining: 39.5s
# 489:	learn: 0.3575587	total: 37.8s	remaining: 39.4s
# 490:	learn: 0.3574187	total: 37.9s	remaining: 39.3s
# 491:	learn: 0.3573315	total: 38s	remaining: 39.2s
# 492:	learn: 0.3572641	total: 38.1s	remaining: 39.2s
# 493:	learn: 0.3571903	total: 38.2s	remaining: 39.1s
# 494:	learn: 0.3568378	total: 38.3s	remaining: 39s
# 495:	learn: 0.3567623	total: 38.3s	remaining: 38.9s
# 496:	learn: 0.3567110	total: 38.4s	remaining: 38.9s
# 497:	learn: 0.3566361	total: 38.5s	remaining: 38.8s
# 498:	learn: 0.3565672	total: 38.6s	remaining: 38.7s
# 499:	learn: 0.3565047	total: 38.6s	remaining: 38.6s
# 500:	learn: 0.3563967	total: 38.7s	remaining: 38.6s
# 501:	learn: 0.3563354	total: 38.8s	remaining: 38.5s
# 502:	learn: 0.3562533	total: 38.9s	remaining: 38.4s
# 503:	learn: 0.3561821	total: 38.9s	remaining: 38.3s
# 504:	learn: 0.3560988	total: 39s	remaining: 38.2s
# 505:	learn: 0.3560218	total: 39.1s	remaining: 38.2s
# 506:	learn: 0.3559558	total: 39.2s	remaining: 38.1s
# 507:	learn: 0.3558616	total: 39.3s	remaining: 38s
# 508:	learn: 0.3558018	total: 39.3s	remaining: 37.9s
# 509:	learn: 0.3557318	total: 39.4s	remaining: 37.9s
# 510:	learn: 0.3556621	total: 39.5s	remaining: 37.8s
# 511:	learn: 0.3555929	total: 39.5s	remaining: 37.7s
# 512:	learn: 0.3555261	total: 39.6s	remaining: 37.6s
# 513:	learn: 0.3554434	total: 39.7s	remaining: 37.5s
# 514:	learn: 0.3553804	total: 39.8s	remaining: 37.5s
# 515:	learn: 0.3552261	total: 39.8s	remaining: 37.4s
# 516:	learn: 0.3551622	total: 39.9s	remaining: 37.3s
# 517:	learn: 0.3550790	total: 40s	remaining: 37.2s
# 518:	learn: 0.3549506	total: 40.1s	remaining: 37.1s
# 519:	learn: 0.3547191	total: 40.1s	remaining: 37.1s
# 520:	learn: 0.3546493	total: 40.2s	remaining: 37s
# 521:	learn: 0.3545432	total: 40.3s	remaining: 36.9s
# 522:	learn: 0.3544637	total: 40.4s	remaining: 36.8s
# 523:	learn: 0.3543804	total: 40.5s	remaining: 36.8s
# 524:	learn: 0.3543095	total: 40.5s	remaining: 36.7s
# 525:	learn: 0.3542383	total: 40.6s	remaining: 36.6s
# 526:	learn: 0.3541397	total: 40.7s	remaining: 36.5s
# 527:	learn: 0.3540229	total: 40.8s	remaining: 36.4s
# 528:	learn: 0.3539382	total: 40.8s	remaining: 36.4s
# 529:	learn: 0.3538602	total: 40.9s	remaining: 36.3s
# 530:	learn: 0.3537887	total: 41s	remaining: 36.2s
# 531:	learn: 0.3536837	total: 41s	remaining: 36.1s
# 532:	learn: 0.3536014	total: 41.1s	remaining: 36s
# 533:	learn: 0.3535317	total: 41.2s	remaining: 35.9s
# 534:	learn: 0.3532576	total: 41.3s	remaining: 35.9s
# 535:	learn: 0.3531960	total: 41.3s	remaining: 35.8s
# 536:	learn: 0.3530919	total: 41.4s	remaining: 35.7s
# 537:	learn: 0.3530233	total: 41.5s	remaining: 35.6s
# 538:	learn: 0.3529389	total: 41.6s	remaining: 35.6s
# 539:	learn: 0.3528672	total: 41.6s	remaining: 35.5s
# 540:	learn: 0.3527867	total: 41.7s	remaining: 35.4s
# 541:	learn: 0.3527703	total: 41.8s	remaining: 35.3s
# 542:	learn: 0.3527590	total: 41.8s	remaining: 35.2s
# 543:	learn: 0.3526731	total: 41.9s	remaining: 35.1s
# 544:	learn: 0.3525460	total: 42s	remaining: 35s
# 545:	learn: 0.3524573	total: 42.1s	remaining: 35s
# 546:	learn: 0.3523821	total: 42.1s	remaining: 34.9s
# 547:	learn: 0.3523114	total: 42.2s	remaining: 34.8s
# 548:	learn: 0.3522319	total: 42.3s	remaining: 34.7s
# 549:	learn: 0.3521486	total: 42.4s	remaining: 34.7s
# 550:	learn: 0.3520766	total: 42.5s	remaining: 34.6s
# 551:	learn: 0.3519851	total: 42.5s	remaining: 34.5s
# 552:	learn: 0.3519749	total: 42.6s	remaining: 34.4s
# 553:	learn: 0.3519008	total: 42.7s	remaining: 34.4s
# 554:	learn: 0.3518072	total: 42.8s	remaining: 34.3s
# 555:	learn: 0.3517473	total: 42.8s	remaining: 34.2s
# 556:	learn: 0.3516762	total: 42.9s	remaining: 34.1s
# 557:	learn: 0.3516644	total: 43s	remaining: 34s
# 558:	learn: 0.3515854	total: 43s	remaining: 34s
# 559:	learn: 0.3515326	total: 43.1s	remaining: 33.9s
# 560:	learn: 0.3514446	total: 43.2s	remaining: 33.8s
# 561:	learn: 0.3513648	total: 43.3s	remaining: 33.7s
# 562:	learn: 0.3512920	total: 43.3s	remaining: 33.6s
# 563:	learn: 0.3512123	total: 43.4s	remaining: 33.6s
# 564:	learn: 0.3510818	total: 43.5s	remaining: 33.5s
# 565:	learn: 0.3510202	total: 43.6s	remaining: 33.4s
# 566:	learn: 0.3509661	total: 43.6s	remaining: 33.3s
# 567:	learn: 0.3509063	total: 43.7s	remaining: 33.3s
# 568:	learn: 0.3508197	total: 43.8s	remaining: 33.2s
# 569:	learn: 0.3507288	total: 43.9s	remaining: 33.1s
# 570:	learn: 0.3506594	total: 43.9s	remaining: 33s
# 571:	learn: 0.3505943	total: 44s	remaining: 32.9s
# 572:	learn: 0.3505447	total: 44.1s	remaining: 32.9s
# 573:	learn: 0.3504651	total: 44.2s	remaining: 32.8s
# 574:	learn: 0.3502962	total: 44.2s	remaining: 32.7s
# 575:	learn: 0.3502245	total: 44.3s	remaining: 32.6s
# 576:	learn: 0.3501421	total: 44.4s	remaining: 32.5s
# 577:	learn: 0.3500841	total: 44.5s	remaining: 32.5s
# 578:	learn: 0.3500202	total: 44.5s	remaining: 32.4s
# 579:	learn: 0.3500017	total: 44.6s	remaining: 32.3s
# 580:	learn: 0.3499289	total: 44.7s	remaining: 32.2s
# 581:	learn: 0.3498258	total: 44.7s	remaining: 32.1s
# 582:	learn: 0.3497642	total: 44.8s	remaining: 32.1s
# 583:	learn: 0.3496959	total: 44.9s	remaining: 32s
# 584:	learn: 0.3496490	total: 45s	remaining: 31.9s
# 585:	learn: 0.3495740	total: 45s	remaining: 31.8s
# 586:	learn: 0.3495108	total: 45.1s	remaining: 31.7s
# 587:	learn: 0.3494183	total: 45.2s	remaining: 31.7s
# 588:	learn: 0.3493181	total: 45.3s	remaining: 31.6s
# 589:	learn: 0.3492680	total: 45.3s	remaining: 31.5s
# 590:	learn: 0.3491830	total: 45.4s	remaining: 31.4s
# 591:	learn: 0.3491142	total: 45.5s	remaining: 31.4s
# 592:	learn: 0.3490419	total: 45.6s	remaining: 31.3s
# 593:	learn: 0.3489594	total: 45.7s	remaining: 31.2s
# 594:	learn: 0.3489021	total: 45.7s	remaining: 31.1s
# 595:	learn: 0.3488267	total: 45.8s	remaining: 31s
# 596:	learn: 0.3487480	total: 45.9s	remaining: 31s
# 597:	learn: 0.3486520	total: 46s	remaining: 30.9s
# 598:	learn: 0.3485815	total: 46s	remaining: 30.8s
# 599:	learn: 0.3482023	total: 46.1s	remaining: 30.7s
# 600:	learn: 0.3481354	total: 46.2s	remaining: 30.7s
# 601:	learn: 0.3480572	total: 46.3s	remaining: 30.6s
# 602:	learn: 0.3480057	total: 46.4s	remaining: 30.5s
# 603:	learn: 0.3479331	total: 46.4s	remaining: 30.4s
# 604:	learn: 0.3478603	total: 46.5s	remaining: 30.4s
# 605:	learn: 0.3477972	total: 46.6s	remaining: 30.3s
# 606:	learn: 0.3477302	total: 46.7s	remaining: 30.2s
# 607:	learn: 0.3476666	total: 46.7s	remaining: 30.1s
# 608:	learn: 0.3475960	total: 46.8s	remaining: 30.1s
# 609:	learn: 0.3475309	total: 46.9s	remaining: 30s
# 610:	learn: 0.3474586	total: 47s	remaining: 29.9s
# 611:	learn: 0.3473976	total: 47s	remaining: 29.8s
# 612:	learn: 0.3473071	total: 47.1s	remaining: 29.8s
# 613:	learn: 0.3472487	total: 47.2s	remaining: 29.7s
# 614:	learn: 0.3470245	total: 47.3s	remaining: 29.6s
# 615:	learn: 0.3469431	total: 47.4s	remaining: 29.5s
# 616:	learn: 0.3468603	total: 47.4s	remaining: 29.4s
# 617:	learn: 0.3467715	total: 47.5s	remaining: 29.4s
# 618:	learn: 0.3466976	total: 47.6s	remaining: 29.3s
# 619:	learn: 0.3466282	total: 47.7s	remaining: 29.2s
# 620:	learn: 0.3465817	total: 47.7s	remaining: 29.1s
# 621:	learn: 0.3465162	total: 47.8s	remaining: 29.1s
# 622:	learn: 0.3464540	total: 47.9s	remaining: 29s
# 623:	learn: 0.3463669	total: 48s	remaining: 28.9s
# 624:	learn: 0.3463583	total: 48s	remaining: 28.8s
# 625:	learn: 0.3462936	total: 48.1s	remaining: 28.7s
# 626:	learn: 0.3461201	total: 48.2s	remaining: 28.7s
# 627:	learn: 0.3460510	total: 48.2s	remaining: 28.6s
# 628:	learn: 0.3459660	total: 48.3s	remaining: 28.5s
# 629:	learn: 0.3459495	total: 48.4s	remaining: 28.4s
# 630:	learn: 0.3458882	total: 48.5s	remaining: 28.3s
# 631:	learn: 0.3457360	total: 48.6s	remaining: 28.3s
# 632:	learn: 0.3457119	total: 48.6s	remaining: 28.2s
# 633:	learn: 0.3456477	total: 48.7s	remaining: 28.1s
# 634:	learn: 0.3455632	total: 48.8s	remaining: 28s
# 635:	learn: 0.3454610	total: 48.9s	remaining: 28s
# 636:	learn: 0.3453746	total: 49s	remaining: 27.9s
# 637:	learn: 0.3453062	total: 49s	remaining: 27.8s
# 638:	learn: 0.3452352	total: 49.1s	remaining: 27.8s
# 639:	learn: 0.3451612	total: 49.2s	remaining: 27.7s
# 640:	learn: 0.3450866	total: 49.3s	remaining: 27.6s
# 641:	learn: 0.3450712	total: 49.4s	remaining: 27.5s
# 642:	learn: 0.3450398	total: 49.4s	remaining: 27.4s
# 643:	learn: 0.3449919	total: 49.5s	remaining: 27.4s
# 644:	learn: 0.3449195	total: 49.6s	remaining: 27.3s
# 645:	learn: 0.3448433	total: 49.7s	remaining: 27.2s
# 646:	learn: 0.3447807	total: 49.8s	remaining: 27.1s
# 647:	learn: 0.3447085	total: 49.8s	remaining: 27.1s
# 648:	learn: 0.3443492	total: 49.9s	remaining: 27s
# 649:	learn: 0.3443160	total: 50s	remaining: 26.9s
# 650:	learn: 0.3442565	total: 50.1s	remaining: 26.8s
# 651:	learn: 0.3442058	total: 50.2s	remaining: 26.8s
# 652:	learn: 0.3441436	total: 50.2s	remaining: 26.7s
# 653:	learn: 0.3440753	total: 50.3s	remaining: 26.6s
# 654:	learn: 0.3440074	total: 50.4s	remaining: 26.5s
# 655:	learn: 0.3439394	total: 50.5s	remaining: 26.5s
# 656:	learn: 0.3438178	total: 50.6s	remaining: 26.4s
# 657:	learn: 0.3436480	total: 50.6s	remaining: 26.3s
# 658:	learn: 0.3436213	total: 50.7s	remaining: 26.2s
# 659:	learn: 0.3435618	total: 50.8s	remaining: 26.2s
# 660:	learn: 0.3435011	total: 50.9s	remaining: 26.1s
# 661:	learn: 0.3434385	total: 51s	remaining: 26s
# 662:	learn: 0.3433914	total: 51s	remaining: 25.9s
# 663:	learn: 0.3433451	total: 51.1s	remaining: 25.9s
# 664:	learn: 0.3432549	total: 51.2s	remaining: 25.8s
# 665:	learn: 0.3431611	total: 51.3s	remaining: 25.7s
# 666:	learn: 0.3431051	total: 51.4s	remaining: 25.6s
# 667:	learn: 0.3430258	total: 51.5s	remaining: 25.6s
# 668:	learn: 0.3429503	total: 51.5s	remaining: 25.5s
# 669:	learn: 0.3428541	total: 51.6s	remaining: 25.4s
# 670:	learn: 0.3427608	total: 51.7s	remaining: 25.4s
# 671:	learn: 0.3427014	total: 51.8s	remaining: 25.3s
# 672:	learn: 0.3426463	total: 51.9s	remaining: 25.2s
# 673:	learn: 0.3425796	total: 51.9s	remaining: 25.1s
# 674:	learn: 0.3424972	total: 52s	remaining: 25s
# 675:	learn: 0.3423593	total: 52.1s	remaining: 25s
# 676:	learn: 0.3423367	total: 52.2s	remaining: 24.9s
# 677:	learn: 0.3422583	total: 52.2s	remaining: 24.8s
# 678:	learn: 0.3421847	total: 52.3s	remaining: 24.7s
# 679:	learn: 0.3421216	total: 52.4s	remaining: 24.7s
# 680:	learn: 0.3420705	total: 52.5s	remaining: 24.6s
# 681:	learn: 0.3419967	total: 52.5s	remaining: 24.5s
# 682:	learn: 0.3419431	total: 52.6s	remaining: 24.4s
# 683:	learn: 0.3418625	total: 52.7s	remaining: 24.3s
# 684:	learn: 0.3417942	total: 52.8s	remaining: 24.3s
# 685:	learn: 0.3416675	total: 52.8s	remaining: 24.2s
# 686:	learn: 0.3416323	total: 52.9s	remaining: 24.1s
# 687:	learn: 0.3415598	total: 53s	remaining: 24s
# 688:	learn: 0.3415034	total: 53s	remaining: 23.9s
# 689:	learn: 0.3414438	total: 53.1s	remaining: 23.9s
# 690:	learn: 0.3413703	total: 53.2s	remaining: 23.8s
# 691:	learn: 0.3413371	total: 53.3s	remaining: 23.7s
# 692:	learn: 0.3412643	total: 53.3s	remaining: 23.6s
# 693:	learn: 0.3410518	total: 53.4s	remaining: 23.6s
# 694:	learn: 0.3409991	total: 53.5s	remaining: 23.5s
# 695:	learn: 0.3408661	total: 53.6s	remaining: 23.4s
# 696:	learn: 0.3408011	total: 53.6s	remaining: 23.3s
# 697:	learn: 0.3407248	total: 53.7s	remaining: 23.2s
# 698:	learn: 0.3406594	total: 53.8s	remaining: 23.2s
# 699:	learn: 0.3404443	total: 53.9s	remaining: 23.1s
# 700:	learn: 0.3403818	total: 53.9s	remaining: 23s
# 701:	learn: 0.3403105	total: 54s	remaining: 22.9s
# 702:	learn: 0.3402547	total: 54.1s	remaining: 22.9s
# 703:	learn: 0.3402379	total: 54.2s	remaining: 22.8s
# 704:	learn: 0.3401749	total: 54.2s	remaining: 22.7s
# 705:	learn: 0.3400596	total: 54.3s	remaining: 22.6s
# 706:	learn: 0.3400082	total: 54.4s	remaining: 22.5s
# 707:	learn: 0.3399495	total: 54.4s	remaining: 22.5s
# 708:	learn: 0.3398730	total: 54.5s	remaining: 22.4s
# 709:	learn: 0.3397946	total: 54.6s	remaining: 22.3s
# 710:	learn: 0.3397051	total: 54.7s	remaining: 22.2s
# 711:	learn: 0.3396370	total: 54.7s	remaining: 22.1s
# 712:	learn: 0.3395796	total: 54.8s	remaining: 22.1s
# 713:	learn: 0.3395155	total: 54.9s	remaining: 22s
# 714:	learn: 0.3394134	total: 55s	remaining: 21.9s
# 715:	learn: 0.3393611	total: 55s	remaining: 21.8s
# 716:	learn: 0.3393046	total: 55.1s	remaining: 21.8s
# 717:	learn: 0.3392349	total: 55.2s	remaining: 21.7s
# 718:	learn: 0.3391748	total: 55.3s	remaining: 21.6s
# 719:	learn: 0.3390917	total: 55.4s	remaining: 21.5s
# 720:	learn: 0.3390501	total: 55.4s	remaining: 21.4s
# 721:	learn: 0.3389817	total: 55.5s	remaining: 21.4s
# 722:	learn: 0.3388053	total: 55.6s	remaining: 21.3s
# 723:	learn: 0.3387390	total: 55.7s	remaining: 21.2s
# 724:	learn: 0.3386887	total: 55.7s	remaining: 21.1s
# 725:	learn: 0.3386307	total: 55.8s	remaining: 21.1s
# 726:	learn: 0.3385747	total: 55.9s	remaining: 21s
# 727:	learn: 0.3385002	total: 55.9s	remaining: 20.9s
# 728:	learn: 0.3384332	total: 56s	remaining: 20.8s
# 729:	learn: 0.3383822	total: 56.1s	remaining: 20.8s
# 730:	learn: 0.3382912	total: 56.2s	remaining: 20.7s
# 731:	learn: 0.3382379	total: 56.3s	remaining: 20.6s
# 732:	learn: 0.3381746	total: 56.4s	remaining: 20.5s
# 733:	learn: 0.3381195	total: 56.4s	remaining: 20.5s
# 734:	learn: 0.3380246	total: 56.5s	remaining: 20.4s
# 735:	learn: 0.3379623	total: 56.6s	remaining: 20.3s
# 736:	learn: 0.3378861	total: 56.7s	remaining: 20.2s
# 737:	learn: 0.3378634	total: 56.7s	remaining: 20.1s
# 738:	learn: 0.3377983	total: 56.8s	remaining: 20.1s
# 739:	learn: 0.3377401	total: 56.9s	remaining: 20s
# 740:	learn: 0.3376809	total: 57s	remaining: 19.9s
# 741:	learn: 0.3376343	total: 57s	remaining: 19.8s
# 742:	learn: 0.3373886	total: 57.1s	remaining: 19.7s
# 743:	learn: 0.3373144	total: 57.2s	remaining: 19.7s
# 744:	learn: 0.3372614	total: 57.2s	remaining: 19.6s
# 745:	learn: 0.3372126	total: 57.3s	remaining: 19.5s
# 746:	learn: 0.3371394	total: 57.4s	remaining: 19.4s
# 747:	learn: 0.3370838	total: 57.5s	remaining: 19.4s
# 748:	learn: 0.3370148	total: 57.5s	remaining: 19.3s
# 749:	learn: 0.3369210	total: 57.6s	remaining: 19.2s
# 750:	learn: 0.3368695	total: 57.7s	remaining: 19.1s
# 751:	learn: 0.3368098	total: 57.8s	remaining: 19s
# 752:	learn: 0.3367482	total: 57.8s	remaining: 19s
# 753:	learn: 0.3367160	total: 57.9s	remaining: 18.9s
# 754:	learn: 0.3366439	total: 58s	remaining: 18.8s
# 755:	learn: 0.3365685	total: 58.1s	remaining: 18.7s
# 756:	learn: 0.3365087	total: 58.1s	remaining: 18.7s
# 757:	learn: 0.3364404	total: 58.2s	remaining: 18.6s
# 758:	learn: 0.3363892	total: 58.3s	remaining: 18.5s
# 759:	learn: 0.3363104	total: 58.4s	remaining: 18.4s
# 760:	learn: 0.3362252	total: 58.5s	remaining: 18.4s
# 761:	learn: 0.3361546	total: 58.5s	remaining: 18.3s
# 762:	learn: 0.3361078	total: 58.6s	remaining: 18.2s
# 763:	learn: 0.3360564	total: 58.7s	remaining: 18.1s
# 764:	learn: 0.3359570	total: 58.8s	remaining: 18.1s
# 765:	learn: 0.3358909	total: 58.8s	remaining: 18s
# 766:	learn: 0.3358041	total: 58.9s	remaining: 17.9s
# 767:	learn: 0.3357265	total: 59s	remaining: 17.8s
# 768:	learn: 0.3356635	total: 59.1s	remaining: 17.8s
# 769:	learn: 0.3355996	total: 59.2s	remaining: 17.7s
# 770:	learn: 0.3355187	total: 59.2s	remaining: 17.6s
# 771:	learn: 0.3354399	total: 59.3s	remaining: 17.5s
# 772:	learn: 0.3353774	total: 59.4s	remaining: 17.4s
# 773:	learn: 0.3353245	total: 59.5s	remaining: 17.4s
# 774:	learn: 0.3352690	total: 59.5s	remaining: 17.3s
# 775:	learn: 0.3351964	total: 59.6s	remaining: 17.2s
# 776:	learn: 0.3351376	total: 59.7s	remaining: 17.1s
# 777:	learn: 0.3351315	total: 59.7s	remaining: 17s
# 778:	learn: 0.3350697	total: 59.8s	remaining: 17s
# 779:	learn: 0.3349983	total: 59.9s	remaining: 16.9s
# 780:	learn: 0.3349372	total: 60s	remaining: 16.8s
# 781:	learn: 0.3348757	total: 1m	remaining: 16.7s
# 782:	learn: 0.3348115	total: 1m	remaining: 16.7s
# 783:	learn: 0.3347483	total: 1m	remaining: 16.6s
# 784:	learn: 0.3347408	total: 1m	remaining: 16.5s
# 785:	learn: 0.3346808	total: 1m	remaining: 16.4s
# 786:	learn: 0.3346169	total: 1m	remaining: 16.4s
# 787:	learn: 0.3345554	total: 1m	remaining: 16.3s
# 788:	learn: 0.3345026	total: 1m	remaining: 16.2s
# 789:	learn: 0.3344274	total: 1m	remaining: 16.1s
# 790:	learn: 0.3343775	total: 1m	remaining: 16.1s
# 791:	learn: 0.3343247	total: 1m	remaining: 16s
# 792:	learn: 0.3342661	total: 1m	remaining: 15.9s
# 793:	learn: 0.3342254	total: 1m	remaining: 15.8s
# 794:	learn: 0.3342195	total: 1m 1s	remaining: 15.7s
# 795:	learn: 0.3341506	total: 1m 1s	remaining: 15.7s
# 796:	learn: 0.3340798	total: 1m 1s	remaining: 15.6s
# 797:	learn: 0.3340330	total: 1m 1s	remaining: 15.5s
# 798:	learn: 0.3339653	total: 1m 1s	remaining: 15.4s
# 799:	learn: 0.3339019	total: 1m 1s	remaining: 15.4s
# 800:	learn: 0.3338254	total: 1m 1s	remaining: 15.3s
# 801:	learn: 0.3337402	total: 1m 1s	remaining: 15.2s
# 802:	learn: 0.3336544	total: 1m 1s	remaining: 15.1s
# 803:	learn: 0.3336295	total: 1m 1s	remaining: 15s
# 804:	learn: 0.3335719	total: 1m 1s	remaining: 15s
# 805:	learn: 0.3335622	total: 1m 1s	remaining: 14.9s
# 806:	learn: 0.3334734	total: 1m 1s	remaining: 14.8s
# 807:	learn: 0.3334174	total: 1m 2s	remaining: 14.7s
# 808:	learn: 0.3333654	total: 1m 2s	remaining: 14.7s
# 809:	learn: 0.3332818	total: 1m 2s	remaining: 14.6s
# 810:	learn: 0.3330455	total: 1m 2s	remaining: 14.5s
# 811:	learn: 0.3329904	total: 1m 2s	remaining: 14.4s
# 812:	learn: 0.3329111	total: 1m 2s	remaining: 14.4s
# 813:	learn: 0.3328905	total: 1m 2s	remaining: 14.3s
# 814:	learn: 0.3328211	total: 1m 2s	remaining: 14.2s
# 815:	learn: 0.3327419	total: 1m 2s	remaining: 14.1s
# 816:	learn: 0.3326338	total: 1m 2s	remaining: 14.1s
# 817:	learn: 0.3325488	total: 1m 2s	remaining: 14s
# 818:	learn: 0.3325022	total: 1m 2s	remaining: 13.9s
# 819:	learn: 0.3324350	total: 1m 3s	remaining: 13.8s
# 820:	learn: 0.3323762	total: 1m 3s	remaining: 13.8s
# 821:	learn: 0.3322655	total: 1m 3s	remaining: 13.7s
# 822:	learn: 0.3322077	total: 1m 3s	remaining: 13.6s
# 823:	learn: 0.3321465	total: 1m 3s	remaining: 13.5s
# 824:	learn: 0.3320785	total: 1m 3s	remaining: 13.5s
# 825:	learn: 0.3319970	total: 1m 3s	remaining: 13.4s
# 826:	learn: 0.3319583	total: 1m 3s	remaining: 13.3s
# 827:	learn: 0.3317601	total: 1m 3s	remaining: 13.2s
# 828:	learn: 0.3316870	total: 1m 3s	remaining: 13.2s
# 829:	learn: 0.3316089	total: 1m 3s	remaining: 13.1s
# 830:	learn: 0.3315339	total: 1m 3s	remaining: 13s
# 831:	learn: 0.3314813	total: 1m 4s	remaining: 12.9s
# 832:	learn: 0.3314112	total: 1m 4s	remaining: 12.9s
# 833:	learn: 0.3314057	total: 1m 4s	remaining: 12.8s
# 834:	learn: 0.3313485	total: 1m 4s	remaining: 12.7s
# 835:	learn: 0.3312500	total: 1m 4s	remaining: 12.6s
# 836:	learn: 0.3310082	total: 1m 4s	remaining: 12.6s
# 837:	learn: 0.3309529	total: 1m 4s	remaining: 12.5s
# 838:	learn: 0.3308798	total: 1m 4s	remaining: 12.4s
# 839:	learn: 0.3308271	total: 1m 4s	remaining: 12.3s
# 840:	learn: 0.3307637	total: 1m 4s	remaining: 12.2s
# 841:	learn: 0.3307093	total: 1m 4s	remaining: 12.2s
# 842:	learn: 0.3306625	total: 1m 4s	remaining: 12.1s
# 843:	learn: 0.3305980	total: 1m 5s	remaining: 12s
# 844:	learn: 0.3305496	total: 1m 5s	remaining: 11.9s
# 845:	learn: 0.3304987	total: 1m 5s	remaining: 11.9s
# 846:	learn: 0.3304442	total: 1m 5s	remaining: 11.8s
# 847:	learn: 0.3303895	total: 1m 5s	remaining: 11.7s
# 848:	learn: 0.3303272	total: 1m 5s	remaining: 11.6s
# 849:	learn: 0.3302514	total: 1m 5s	remaining: 11.6s
# 850:	learn: 0.3301886	total: 1m 5s	remaining: 11.5s
# 851:	learn: 0.3301446	total: 1m 5s	remaining: 11.4s
# 852:	learn: 0.3301205	total: 1m 5s	remaining: 11.3s
# 853:	learn: 0.3300922	total: 1m 5s	remaining: 11.2s
# 854:	learn: 0.3299456	total: 1m 5s	remaining: 11.2s
# 855:	learn: 0.3299049	total: 1m 5s	remaining: 11.1s
# 856:	learn: 0.3298358	total: 1m 6s	remaining: 11s
# 857:	learn: 0.3297295	total: 1m 6s	remaining: 10.9s
# 858:	learn: 0.3296776	total: 1m 6s	remaining: 10.9s
# 859:	learn: 0.3296723	total: 1m 6s	remaining: 10.8s
# 860:	learn: 0.3296208	total: 1m 6s	remaining: 10.7s
# 861:	learn: 0.3295682	total: 1m 6s	remaining: 10.6s
# 862:	learn: 0.3294786	total: 1m 6s	remaining: 10.5s
# 863:	learn: 0.3292647	total: 1m 6s	remaining: 10.5s
# 864:	learn: 0.3292047	total: 1m 6s	remaining: 10.4s
# 865:	learn: 0.3291565	total: 1m 6s	remaining: 10.3s
# 866:	learn: 0.3290783	total: 1m 6s	remaining: 10.2s
# 867:	learn: 0.3289969	total: 1m 6s	remaining: 10.2s
# 868:	learn: 0.3289374	total: 1m 6s	remaining: 10.1s
# 869:	learn: 0.3288721	total: 1m 6s	remaining: 10s
# 870:	learn: 0.3288289	total: 1m 7s	remaining: 9.93s
# 871:	learn: 0.3287884	total: 1m 7s	remaining: 9.85s
# 872:	learn: 0.3287035	total: 1m 7s	remaining: 9.78s
# 873:	learn: 0.3286386	total: 1m 7s	remaining: 9.7s
# 874:	learn: 0.3285863	total: 1m 7s	remaining: 9.62s
# 875:	learn: 0.3285223	total: 1m 7s	remaining: 9.54s
# 876:	learn: 0.3284594	total: 1m 7s	remaining: 9.47s
# 877:	learn: 0.3284029	total: 1m 7s	remaining: 9.39s
# 878:	learn: 0.3283383	total: 1m 7s	remaining: 9.31s
# 879:	learn: 0.3282947	total: 1m 7s	remaining: 9.24s
# 880:	learn: 0.3282896	total: 1m 7s	remaining: 9.16s
# 881:	learn: 0.3282346	total: 1m 7s	remaining: 9.08s
# 882:	learn: 0.3282068	total: 1m 7s	remaining: 9s
# 883:	learn: 0.3281483	total: 1m 8s	remaining: 8.92s
# 884:	learn: 0.3281419	total: 1m 8s	remaining: 8.85s
# 885:	learn: 0.3280957	total: 1m 8s	remaining: 8.77s
# 886:	learn: 0.3280250	total: 1m 8s	remaining: 8.69s
# 887:	learn: 0.3279547	total: 1m 8s	remaining: 8.62s
# 888:	learn: 0.3278763	total: 1m 8s	remaining: 8.54s
# 889:	learn: 0.3278186	total: 1m 8s	remaining: 8.46s
# 890:	learn: 0.3277837	total: 1m 8s	remaining: 8.39s
# 891:	learn: 0.3277266	total: 1m 8s	remaining: 8.31s
# 892:	learn: 0.3276654	total: 1m 8s	remaining: 8.23s
# 893:	learn: 0.3276097	total: 1m 8s	remaining: 8.15s
# 894:	learn: 0.3275677	total: 1m 8s	remaining: 8.08s
# 895:	learn: 0.3275075	total: 1m 8s	remaining: 8s
# 896:	learn: 0.3274308	total: 1m 9s	remaining: 7.92s
# 897:	learn: 0.3273938	total: 1m 9s	remaining: 7.85s
# 898:	learn: 0.3273574	total: 1m 9s	remaining: 7.77s
# 899:	learn: 0.3272960	total: 1m 9s	remaining: 7.69s
# 900:	learn: 0.3272727	total: 1m 9s	remaining: 7.61s
# 901:	learn: 0.3272107	total: 1m 9s	remaining: 7.54s
# 902:	learn: 0.3271274	total: 1m 9s	remaining: 7.46s
# 903:	learn: 0.3270514	total: 1m 9s	remaining: 7.38s
# 904:	learn: 0.3269725	total: 1m 9s	remaining: 7.31s
# 905:	learn: 0.3269089	total: 1m 9s	remaining: 7.23s
# 906:	learn: 0.3268527	total: 1m 9s	remaining: 7.15s
# 907:	learn: 0.3268273	total: 1m 9s	remaining: 7.07s
# 908:	learn: 0.3268008	total: 1m 9s	remaining: 7s
# 909:	learn: 0.3267450	total: 1m 9s	remaining: 6.92s
# 910:	learn: 0.3267398	total: 1m 10s	remaining: 6.84s
# 911:	learn: 0.3266825	total: 1m 10s	remaining: 6.76s
# 912:	learn: 0.3265982	total: 1m 10s	remaining: 6.69s
# 913:	learn: 0.3265937	total: 1m 10s	remaining: 6.61s
# 914:	learn: 0.3265198	total: 1m 10s	remaining: 6.53s
# 915:	learn: 0.3264594	total: 1m 10s	remaining: 6.46s
# 916:	learn: 0.3263892	total: 1m 10s	remaining: 6.38s
# 917:	learn: 0.3263224	total: 1m 10s	remaining: 6.3s
# 918:	learn: 0.3262683	total: 1m 10s	remaining: 6.23s
# 919:	learn: 0.3261980	total: 1m 10s	remaining: 6.15s
# 920:	learn: 0.3261378	total: 1m 10s	remaining: 6.07s
# 921:	learn: 0.3260755	total: 1m 10s	remaining: 5.99s
# 922:	learn: 0.3260422	total: 1m 10s	remaining: 5.92s
# 923:	learn: 0.3258805	total: 1m 11s	remaining: 5.84s
# 924:	learn: 0.3258167	total: 1m 11s	remaining: 5.76s
# 925:	learn: 0.3258031	total: 1m 11s	remaining: 5.68s
# 926:	learn: 0.3256619	total: 1m 11s	remaining: 5.61s
# 927:	learn: 0.3256422	total: 1m 11s	remaining: 5.53s
# 928:	learn: 0.3255494	total: 1m 11s	remaining: 5.45s
# 929:	learn: 0.3254991	total: 1m 11s	remaining: 5.38s
# 930:	learn: 0.3254572	total: 1m 11s	remaining: 5.3s
# 931:	learn: 0.3253920	total: 1m 11s	remaining: 5.22s
# 932:	learn: 0.3251321	total: 1m 11s	remaining: 5.14s
# 933:	learn: 0.3250741	total: 1m 11s	remaining: 5.07s
# 934:	learn: 0.3250087	total: 1m 11s	remaining: 4.99s
# 935:	learn: 0.3249675	total: 1m 11s	remaining: 4.91s
# 936:	learn: 0.3249085	total: 1m 11s	remaining: 4.84s
# 937:	learn: 0.3248499	total: 1m 12s	remaining: 4.76s
# 938:	learn: 0.3247840	total: 1m 12s	remaining: 4.68s
# 939:	learn: 0.3246970	total: 1m 12s	remaining: 4.61s
# 940:	learn: 0.3246922	total: 1m 12s	remaining: 4.53s
# 941:	learn: 0.3246187	total: 1m 12s	remaining: 4.45s
# 942:	learn: 0.3245568	total: 1m 12s	remaining: 4.38s
# 943:	learn: 0.3245201	total: 1m 12s	remaining: 4.3s
# 944:	learn: 0.3244618	total: 1m 12s	remaining: 4.22s
# 945:	learn: 0.3244048	total: 1m 12s	remaining: 4.14s
# 946:	learn: 0.3244001	total: 1m 12s	remaining: 4.07s
# 947:	learn: 0.3243294	total: 1m 12s	remaining: 3.99s
# 948:	learn: 0.3243070	total: 1m 12s	remaining: 3.91s
# 949:	learn: 0.3242508	total: 1m 12s	remaining: 3.84s
# 950:	learn: 0.3241409	total: 1m 12s	remaining: 3.76s
# 951:	learn: 0.3241344	total: 1m 13s	remaining: 3.68s
# 952:	learn: 0.3240841	total: 1m 13s	remaining: 3.6s
# 953:	learn: 0.3240386	total: 1m 13s	remaining: 3.53s
# 954:	learn: 0.3239622	total: 1m 13s	remaining: 3.45s
# 955:	learn: 0.3238937	total: 1m 13s	remaining: 3.38s
# 956:	learn: 0.3238392	total: 1m 13s	remaining: 3.3s
# 957:	learn: 0.3237563	total: 1m 13s	remaining: 3.22s
# 958:	learn: 0.3237353	total: 1m 13s	remaining: 3.14s
# 959:	learn: 0.3236781	total: 1m 13s	remaining: 3.07s
# 960:	learn: 0.3236478	total: 1m 13s	remaining: 2.99s
# 961:	learn: 0.3235915	total: 1m 13s	remaining: 2.91s
# 962:	learn: 0.3235029	total: 1m 13s	remaining: 2.84s
# 963:	learn: 0.3234360	total: 1m 13s	remaining: 2.76s
# 964:	learn: 0.3233780	total: 1m 13s	remaining: 2.68s
# 965:	learn: 0.3233211	total: 1m 14s	remaining: 2.61s
# 966:	learn: 0.3232514	total: 1m 14s	remaining: 2.53s
# 967:	learn: 0.3231905	total: 1m 14s	remaining: 2.45s
# 968:	learn: 0.3231360	total: 1m 14s	remaining: 2.38s
# 969:	learn: 0.3230867	total: 1m 14s	remaining: 2.3s
# 970:	learn: 0.3230371	total: 1m 14s	remaining: 2.22s
# 971:	learn: 0.3230324	total: 1m 14s	remaining: 2.15s
# 972:	learn: 0.3229783	total: 1m 14s	remaining: 2.07s
# 973:	learn: 0.3229168	total: 1m 14s	remaining: 1.99s
# 974:	learn: 0.3228627	total: 1m 14s	remaining: 1.92s
# 975:	learn: 0.3228167	total: 1m 14s	remaining: 1.84s
# 976:	learn: 0.3227442	total: 1m 14s	remaining: 1.76s
# 977:	learn: 0.3227045	total: 1m 14s	remaining: 1.69s
# 978:	learn: 0.3226613	total: 1m 15s	remaining: 1.61s
# 979:	learn: 0.3225870	total: 1m 15s	remaining: 1.53s
# 980:	learn: 0.3225446	total: 1m 15s	remaining: 1.46s
# 981:	learn: 0.3225151	total: 1m 15s	remaining: 1.38s
# 982:	learn: 0.3224892	total: 1m 15s	remaining: 1.3s
# 983:	learn: 0.3224348	total: 1m 15s	remaining: 1.23s
# 984:	learn: 0.3223763	total: 1m 15s	remaining: 1.15s
# 985:	learn: 0.3223715	total: 1m 15s	remaining: 1.07s
# 986:	learn: 0.3222966	total: 1m 15s	remaining: 996ms
# 987:	learn: 0.3222213	total: 1m 15s	remaining: 919ms
# 988:	learn: 0.3221747	total: 1m 15s	remaining: 843ms
# 989:	learn: 0.3221283	total: 1m 15s	remaining: 766ms
# 990:	learn: 0.3221078	total: 1m 15s	remaining: 689ms
# 991:	learn: 0.3220462	total: 1m 16s	remaining: 613ms
# 992:	learn: 0.3219907	total: 1m 16s	remaining: 536ms
# 993:	learn: 0.3219295	total: 1m 16s	remaining: 460ms
# 994:	learn: 0.3218765	total: 1m 16s	remaining: 383ms
# 995:	learn: 0.3216557	total: 1m 16s	remaining: 307ms
# 996:	learn: 0.3215707	total: 1m 16s	remaining: 230ms
# 997:	learn: 0.3215663	total: 1m 16s	remaining: 153ms
# 998:	learn: 0.3215021	total: 1m 16s	remaining: 76.7ms
# 999:	learn: 0.3214425	total: 1m 16s	remaining: 0us
# accuracy score: 0.8393090405724201
# f1 score: 0.8224931082012406

# %%
# train xgboost

model_xgb = train_xgb(X_smote_train, y_smote_train, X_smote_test, y_smote_test)
# Out:
# f1 score: 0.8097169377430279

# %%
# train ann

model_ann = train_ann_tw_onehot(X_smote_train, y_smote_train, X_smote_test, y_smote_test)
# Out:
# Epoch 1/10
# 6412/6412 [==============================] - 32s 4ms/step - loss: 0.6101 - accuracy: 0.6651 - val_loss: 0.5798 - val_accuracy: 0.6963
# Epoch 2/10
# 6412/6412 [==============================] - 23s 4ms/step - loss: 0.5475 - accuracy: 0.7233 - val_loss: 0.5414 - val_accuracy: 0.7289
# Epoch 3/10
# 6412/6412 [==============================] - 23s 4ms/step - loss: 0.5018 - accuracy: 0.7560 - val_loss: 0.5318 - val_accuracy: 0.7411
# Epoch 4/10
# 6412/6412 [==============================] - 23s 4ms/step - loss: 0.4635 - accuracy: 0.7802 - val_loss: 0.5175 - val_accuracy: 0.7467
# Epoch 5/10
# 6412/6412 [==============================] - 23s 4ms/step - loss: 0.4329 - accuracy: 0.7992 - val_loss: 0.5023 - val_accuracy: 0.7615
# Epoch 6/10
# 6412/6412 [==============================] - 24s 4ms/step - loss: 0.4073 - accuracy: 0.8129 - val_loss: 0.4851 - val_accuracy: 0.7719
# Epoch 7/10
# 6412/6412 [==============================] - 23s 4ms/step - loss: 0.3851 - accuracy: 0.8263 - val_loss: 0.4826 - val_accuracy: 0.7759
# Epoch 8/10
# 6412/6412 [==============================] - 23s 4ms/step - loss: 0.3667 - accuracy: 0.8365 - val_loss: 0.4815 - val_accuracy: 0.7732
# Epoch 9/10
# 6412/6412 [==============================] - 23s 4ms/step - loss: 0.3508 - accuracy: 0.8445 - val_loss: 0.4970 - val_accuracy: 0.7784
# Epoch 10/10
# 6412/6412 [==============================] - 23s 4ms/step - loss: 0.3360 - accuracy: 0.8519 - val_loss: 0.4929 - val_accuracy: 0.7881
# 1603/1603 [==============================] - 2s 1ms/step
# f1 score: 0.7903620965719466
